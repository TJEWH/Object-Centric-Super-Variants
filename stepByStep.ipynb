# %%
from ocpa.objects.log.importer.ocel import factory as ocel_import_factory
from ocpa.visualization.log.variants import factory as variants_visualization_factory

import Super_Variant_Definition as SVD
import Super_Variant_Hierarchy as SVH
import Super_Variant_Visualization as SVV
import Intra_Variant_Generation as IAVG
import Intra_Variant_Summarization as IAVS
import Summarization_Selection as IASS
import Inter_Variant_Generation as IEVG
import Input_Extraction_Definition as IED
import Inter_Lane_Alignment as ILA

from Evaluation.templates import (build_triad_hierarchy, print_hierarchy_costs)
from config import P2P_LOG, TEST_LOGS_3, BPI_2017_TOP10_LOG

VISUALIZE_INTERMEDIATE_RESULTS = False

# %%
# EVALUATION Settings
ILA.ALIGN = False
filename = TEST_LOGS_3[1] # P2P_LOG

# Import Log
ocel = ocel_import_factory.apply(file_path=filename)

# %% [markdown]
# ## Intra-Variant Summarization

# %%
### FUNCTION IED.get_unique_summarizations_from_process()
from ocpa.visualization.log.variants import factory as variants_visualization_factory

# -> Division into discrete steps already happens here, viz package part of process discovery in ocpa
# {Activity: [start index, end index], [other appearances / intersections]}
variant_layout = variants_visualization_factory.apply(ocel)
print("Base Variants from ocel:\n", variant_layout, "\n\n\n")
variants = []

# Actually iterated over all variants
sample_variant = 0

# Extract lanes from variant
extracted_variant = IED.extract_lanes(variant_layout[ocel.variants[sample_variant]], ocel.variant_frequencies[sample_variant])
variants.append(extracted_variant)
print("Extracted Variant:\n", extracted_variant, "\n\n\n")

# summarize the variant, then added to all_summarizations
extracted_summarizations = IAVS.within_variant_summarization(extracted_variant, print_results=False)
sample_summarization = extracted_summarizations[0]
# sample_summarization added to list of all summarizations
print("Extracted Summarization:\n", sample_summarization, "\n\n\n")

encoding = sample_summarization.encode_lexicographically()
# encoding used as key in dict to store all unique summarizations
# as values, add for index 0 the variant number and for index 1 the summarization 
# -> {encoding: {0: [variant_number], 1: [summarization]}}
# encoding used als key in set to store all unique summarizations 
# -> {(encoding, [summarization])}
print("Encoding:\n", encoding, "\n\n\n")

### FUNCTION IAVG.complete_intra_variant_summarization_from_process
# BAD SCALABILITY this line
universe, summ_dict = IAVG.get_unique_summarizations_from_process(ocel, print_results=True)
# Sorts the unique summarizations into subsets based on the variants that they summarize.
all_summ, summ_per_variant = IAVG.__determine_subsets(universe, summ_dict)
print("All Summarizations:\n", all_summ[0], "\n")
print("Per Variant Dict:\n", summ_per_variant[0], "\n")
print("Per Encoding Dict:\n", summ_dict, "\n\n\n")





# Generate and select intra-variant summarizations
all_summarizations, per_variant_dict, per_encoding_dict = IAVG.complete_intra_variant_summarization_from_process(ocel, print_results=False)

intra_variant_summarizations = IASS.intra_variant_summarization_selection(all_summarizations, per_variant_dict, per_encoding_dict)
print("Intra Variant Summarizations:\n", intra_variant_summarizations[0], "\n\n\n")

try:
    # EVALUATION Settings
    # Cleansing with actual frequencies
    global_frequencies = [0.069, 0.05, 0.047, 0.03, 0.025, 0.019, 0.019, 0.018, 0.017, 0.016]
    for i in range(len(intra_variant_summarizations)):
        intra_variant_summarizations[i].frequency = global_frequencies[i]
    
    # Visualize selected intra-variant summarizations
    if VISUALIZE_INTERMEDIATE_RESULTS:
        for i in range(len(intra_variant_summarizations)):
            SVV.visualize_super_variant(intra_variant_summarizations[i])
    
    if VISUALIZE_INTERMEDIATE_RESULTS:
        # Visualize intra-variant summarizations of variant v_3
        SVV.MARK_INCORRECT_INTERACTIONS = False
        SVV.visualize_variant(all_summarizations[3][1][1][0],3)
        SVV.visualize_variant(all_summarizations[4][1][1][0],3)
        SVV.MARK_INCORRECT_INTERACTIONS = True
except:
    for x in intra_variant_summarizations:
        print(x)
# Out:
# Base Variants from ocel:
#  {'2f0668d314707f04bc9b32e8e27e37c2': ([['A', [[0, 0], [0, 3, 1, 2]]], ['C', [[1, 2], [0]]], ['D', [[3, 3], [3, 1, 0, 2]]], ['E', [[1, 1], [1]]], ['F', [[2, 2], [1]]], ['H', [[0, 3], [4]]], ['J', [[4, 4], [4, 2]]], ['G', [[1, 2], [2]]], ['F', [[2, 2], [3]]], ['E', [[1, 1], [3]]]], {0: ('a', 'a_1'), 1: ('b', 'b_1'), 2: ('b', 'b_2'), 3: ('b', 'b_3'), 4: ('c', 'c_1')}), 'b7bb62748caf60050ae9c8bbf4b4e349': ([['F', [[2, 2], [1]]], ['E', [[1, 1], [1]]], ['A', [[0, 0], [3, 2, 1, 0]]], ['C', [[1, 2], [0]]], ['D', [[3, 3], [3, 2, 1, 0]]], ['E', [[1, 1], [2]]], ['F', [[2, 2], [2]]], ['H', [[0, 3], [4]]], ['J', [[4, 4], [3, 4]]]], {0: ('a', 'a_1'), 1: ('b', 'b_1'), 2: ('b', 'b_2'), 3: ('b', 'b_3'), 4: ('c', 'c_1')}), '769aecd84fbc1f2d55701ebe0063bb7c': ([['A', [[0, 0], [0, 1]]], ['B', [[1, 1], [0]]], ['C', [[2, 2], [0]]], ['D', [[3, 3], [0, 1]]], ['E', [[1, 1], [1]]], ['F', [[2, 2], [1]]], ['H', [[0, 3], [2]]], ['J', [[4, 4], [2, 1]]]], {0: ('a', 'a_1'), 1: ('b', 'b_1'), 2: ('c', 'c_1')}), 'd7130ca4a23820ac6fff81636f88c593': ([['A', [[0, 0], [1, 0, 2, 3]]], ['C', [[1, 2], [0]]], ['D', [[3, 3], [1, 0, 2, 3]]], ['G', [[1, 2], [3]]], ['G', [[1, 2], [2]]], ['E', [[1, 1], [1]]], ['F', [[2, 2], [1]]]], {0: ('a', 'a_1'), 1: ('b', 'b_1'), 2: ('b', 'b_2'), 3: ('b', 'b_3')})}
#
#
#
# Extracted Variant:
#  Lanes:
# ID: 0, Name: a_1: [(Pos: 0, A),(Pos: 1, C),(Pos: 3, D)]
# ID: 1, Name: b_1: [(Pos: 0, A),(Pos: 1, E),(Pos: 2, F),(Pos: 3, D)]
# ID: 2, Name: b_2: [(Pos: 0, A),(Pos: 1, G),(Pos: 3, D),(Pos: 4, J)]
# ID: 3, Name: b_3: [(Pos: 0, A),(Pos: 1, E),(Pos: 2, F),(Pos: 3, D)]
# ID: 4, Name: c_1: [(Pos: 0, H),(Pos: 4, J)]
#
# Involved Objects:
# {'b', 'a', 'c'}
#
# Interaction Points:
# Interaction Point: A at Pos: 0
# Interaction Point: D at Pos: 3
# Interaction Point: J at Pos: 4
# Frequency: 0.25
#
#
#
# Extracted Summarization:
#  Lanes:
# ID: (0,), Name: a 0, Cardinality: 1:  [(Pos B(0, 0): Interaction A),(Pos B(0, 2): C),(Pos B(0, 3): Interaction D)]
# ID: (2,), Name: b 0, Cardinality: 1:  [(Pos B(0, 0): Interaction A),(Pos B(0, 2): G),(Pos B(0, 3): Interaction D),(Pos B(0, 4): Interaction J)]
# ID: (3, 1), Name: b 1, Cardinality: n:  [(Pos B(0, 0): Interaction A),(Pos B(0, 1): E),(Pos B(0, 2): F),(Pos B(0, 3): Interaction D)]
# ID: (4,), Name: c 0, Cardinality: 1:  [(Pos B(0, 3): H),(Pos B(0, 4): Interaction J)]
#
# Involved Objects:
# {'b', 'a', 'c'}
#
# Interaction Points:
# Interaction Point: A at Pos: 0
# Interaction Point: A at Pos: 0
# Interaction Point: D at Pos: 3
# Interaction Point: D at Pos: 3
# Interaction Point: J at Pos: 4
# Frequency: 0.25
#
#
#
# Encoding:
#  a 0: CAR 1: IP[0:0, A] CO[2:2, C] IP[3:3, D] b 0: CAR 1: IP[0:0, A] CO[2:2, G] IP[3:3, D] IP[4:4, J] b 1: CAR n: IP[0:0, A] CO[1:1, E] CO[2:2, F] IP[3:3, D] c 0: CAR 1: CO[3:3, H] IP[4:4, J] - IP[0,[a 0, b 0, b 1]] IP[0,[a 0, b 0, b 1]] IP[3,[a 0, b 0, b 1]] IP[3,[a 0, b 0, b 1]] IP[4,[b 0, c 0]]
#   0%|          | 0/4 [00:00<?, ?it/s]
#
# Summarizing variant 0 of the process...
# ------------------------------------------
# Current Level: 1
# ----
# Summarizing Lanes: [0]
#
# Adding the common activity: A
# This is an interaction point: True
#
# Adding the common activity: C
# This is an interaction point: False
#
# Adding the common activity: D
# This is an interaction point: True
# ------------------------------------------
# Current Level: 2
# ----
# Summarizing Lanes: [3]
#
# Adding the common activity: A
# This is an interaction point: True
#
# Adding the common activity: E
# This is an interaction point: False
#
# Adding the common activity: F
# This is an interaction point: False
#
# Adding the common activity: D
# This is an interaction point: True
# ----
# Summarizing Lanes: [1]
#
# Adding the common activity: A
# This is an interaction point: True
#
# Adding the common activity: E
# This is an interaction point: False
#
# Adding the common activity: F
# This is an interaction point: False
#
# Adding the common activity: D
# This is an interaction point: True
# ----
# Redundancy found, pruning subtree!
#
#
# ------------------------------------------
# Current Level: 2
# ----
# Summarizing Lanes: [3, 1]
#
# Adding the common activity: A
# This is an interaction point: True
#
# Adding the common activity: E
# This is an interaction point: False
#
# Adding the common activity: F
# This is an interaction point: False
#
# Adding the common activity: D
# This is an interaction point: True
# ------------------------------------------
# Current Level: 3
# ----
# Summarizing Lanes: [2]
#
# Adding the common activity: A
# This is an interaction point: True
#
# Adding the common activity: G
# This is an interaction point: False
#
# Adding the common activity: D
# This is an interaction point: True
#
# Adding the common activity: J
# This is an interaction point: True
# ------------------------------------------
# Current Level: 4
# ----
# Summarizing Lanes: [4]
#
# Adding the common activity: H
# This is an interaction point: False
#
# Adding the common activity: J
# This is an interaction point: True
# ----
# Leaf node reached!
#
#
#
#
#
#
#
#
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 0)
# (3, 1): B(0, 0)
# (2,): B(0, 0)
# No alignment required.
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 0)
# (3, 1): B(0, 0)
# (2,): B(0, 0)
# No alignment required.
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 2)
# (3, 1): B(0, 3)
# (2,): B(0, 2)
# We have shifted lane a i by 1 starting from the element at the position B(0, 2).
# We have shifted lane b i by 1 starting from the element at the position B(0, 2).
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 3)
# (3, 1): B(0, 3)
# (2,): B(0, 3)
# No alignment required.
# We have an interaction at the following positions in the interacting lanes:
# (2,): B(0, 4)
# (4,): B(0, 1)
# We have shifted lane c i by 3 starting from the element at the position B(0, 1).
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 0)
# (3, 1): B(0, 0)
# (2,): B(0, 0)
# No alignment required.
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 0)
# (3, 1): B(0, 0)
# (2,): B(0, 0)
# No alignment required.
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 3)
# (3, 1): B(0, 3)
# (2,): B(0, 3)
# No alignment required.
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 3)
# (3, 1): B(0, 3)
# (2,): B(0, 3)
# No alignment required.
# We have an interaction at the following positions in the interacting lanes:
# (2,): B(0, 4)
# (4,): B(0, 4)
# No alignment required.
# Lanes:
# ID: (0,), Name: a 0, Cardinality: 1:  [(Pos B(0, 0): Interaction A),(Pos B(0, 2): C),(Pos B(0, 3): Interaction D)]
# ID: (2,), Name: b 0, Cardinality: 1:  [(Pos B(0, 0): Interaction A),(Pos B(0, 2): G),(Pos B(0, 3): Interaction D),(Pos B(0, 4): Interaction J)]
# ID: (3, 1), Name: b 1, Cardinality: n:  [(Pos B(0, 0): Interaction A),(Pos B(0, 1): E),(Pos B(0, 2): F),(Pos B(0, 3): Interaction D)]
# ID: (4,), Name: c 0, Cardinality: 1:  [(Pos B(0, 3): H),(Pos B(0, 4): Interaction J)]
#
# Involved Objects:
# {'b', 'a', 'c'}
#
# Interaction Points:
# Interaction Point: A at Pos: 0
# Interaction Point: A at Pos: 0
# Interaction Point: D at Pos: 3
# Interaction Point: D at Pos: 3
# Interaction Point: J at Pos: 4
# Frequency: 0.25
# -------------------
#
# Summarizing variant 1 of the process...
# ------------------------------------------
# Current Level: 1
# ----
# Summarizing Lanes: [0]
#
# Adding the common activity: A
# This is an interaction point: True
#
# Adding the common activity: C
# This is an interaction point: False
#
# Adding the common activity: D
# This is an interaction point: True
# ------------------------------------------
# Current Level: 2
# ----
# Summarizing Lanes: [1]
#
# Adding the common activity: A
# This is an interaction point: True
#
# Adding the common activity: E
# This is an interaction point: False
#
# Adding the common activity: F
# This is an interaction point: False
#
# Adding the common activity: D
# This is an interaction point: True
# ----
# Summarizing Lanes: [2]
#
# Adding the common activity: A
# This is an interaction point: True
#
# Adding the common activity: E
# This is an interaction point: False
#
# Adding the common activity: F
# This is an interaction point: False
#
# Adding the common activity: D
# This is an interaction point: True
# ----
# Redundancy found, pruning subtree!
#
#
# ------------------------------------------
# Current Level: 2
# ----
# Summarizing Lanes: [1, 2]
#
# Adding the common activity: A
# This is an interaction point: True
#
# Adding the common activity: E
# This is an interaction point: False
#
# Adding the common activity: F
# This is an interaction point: False
#
# Adding the common activity: D
# This is an interaction point: True
# ------------------------------------------
# Current Level: 3
# ----
# Summarizing Lanes: [3]
#
# Adding the common activity: A
# This is an interaction point: True
#
# Adding the common activity: D
# This is an interaction point: True
#
# Adding the common activity: J
# This is an interaction point: True
# ------------------------------------------
# Current Level: 4
# ----
# Summarizing Lanes: [4]
#
# Adding the common activity: H
# This is an interaction point: False
#
# Adding the common activity: J
# This is an interaction point: True
# ----
# Leaf node reached!
#
#
#
#
#
#
#
#
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 0)
# (1, 2): B(0, 0)
# (3,): B(0, 0)
# No alignment required.
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 0)
# (1, 2): B(0, 0)
# (3,): B(0, 0)
# No alignment required.
# We have an interaction at the following positions in the interacting lanes:
# (3,): B(0, 2)
# (4,): B(0, 1)
# We have shifted lane c i by 1 starting from the element at the position B(0, 1).
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 2)
# (1, 2): B(0, 3)
# (3,): B(0, 1)
# We have shifted lane a i by 1 starting from the element at the position B(0, 2).
# We have shifted lane b i by 2 starting from the element at the position B(0, 1).
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 3)
# (1, 2): B(0, 3)
# (3,): B(0, 3)
# No alignment required.
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 0)
# (1, 2): B(0, 0)
# (3,): B(0, 0)
# No alignment required.
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 0)
# (1, 2): B(0, 0)
# (3,): B(0, 0)
# No alignment required.
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 3)
# (1, 2): B(0, 3)
# (3,): B(0, 3)
# No alignment required.
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 3)
# (1, 2): B(0, 3)
# (3,): B(0, 3)
# No alignment required.
# We have an interaction at the following positions in the interacting lanes:
# (3,): B(0, 4)
# (4,): B(0, 2)
# We have shifted lane c i by 2 starting from the element at the position B(0, 2).
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 0)
# (1, 2): B(0, 0)
# (3,): B(0, 0)
# No alignment required.
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 0)
# (1, 2): B(0, 0)
# (3,): B(0, 0)
# No alignment required.
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 3)
# (1, 2): B(0, 3)
# (3,): B(0, 3)
# No alignment required.
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 3)
# (1, 2): B(0, 3)
# (3,): B(0, 3)
# No alignment required.
# We have an interaction at the following positions in the interacting lanes:
# (3,): B(0, 4)
# (4,): B(0, 4)
# No alignment required.
# Lanes:
# ID: (0,), Name: a 0, Cardinality: 1:  [(Pos B(0, 0): Interaction A),(Pos B(0, 2): C),(Pos B(0, 3): Interaction D)]
# ID: (3,), Name: b 0, Cardinality: 1:  [(Pos B(0, 0): Interaction A),(Pos B(0, 3): Interaction D),(Pos B(0, 4): Interaction J)]
# ID: (1, 2), Name: b 1, Cardinality: n:  [(Pos B(0, 0): Interaction A),(Pos B(0, 1): E),(Pos B(0, 2): F),(Pos B(0, 3): Interaction D)]
# ID: (4,), Name: c 0, Cardinality: 1:  [(Pos B(0, 3): H),(Pos B(0, 4): Interaction J)]
#
# Involved Objects:
# {'b', 'a', 'c'}
#
# Interaction Points:
# Interaction Point: A at Pos: 0
# Interaction Point: A at Pos: 0
# Interaction Point: D at Pos: 3
# Interaction Point: D at Pos: 3
# Interaction Point: J at Pos: 4
# Frequency: 0.25
# -------------------
#
# Summarizing variant 2 of the process...
# ------------------------------------------
# Current Level: 1
# ----
# Summarizing Lanes: [0]
#
# Adding the common activity: A
# This is an interaction point: True
#
# Adding the common activity: B
# This is an interaction point: False
#
# Adding the common activity: C
# This is an interaction point: False
#
# Adding the common activity: D
# This is an interaction point: True
# ------------------------------------------
# Current Level: 2
# ----
# Summarizing Lanes: [1]
#
# Adding the common activity: A
# This is an interaction point: True
#
# Adding the common activity: E
# This is an interaction point: False
#
# Adding the common activity: F
# This is an interaction point: False
#
# Adding the common activity: D
# This is an interaction point: True
#
# Adding the common activity: J
# This is an interaction point: True
# ------------------------------------------
# Current Level: 3
# ----
# Summarizing Lanes: [2]
#
# Adding the common activity: H
# This is an interaction point: False
#
# Adding the common activity: J
# This is an interaction point: True
# ----
# Leaf node reached!
#
#
#
#
#
#
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 0)
# (1,): B(0, 0)
# No alignment required.
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 3)
# (1,): B(0, 3)
# No alignment required.
# We have an interaction at the following positions in the interacting lanes:
# (1,): B(0, 4)
# (2,): B(0, 1)
# We have shifted lane c i by 3 starting from the element at the position B(0, 1).
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 0)
# (1,): B(0, 0)
# No alignment required.
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 3)
# (1,): B(0, 3)
# No alignment required.
# We have an interaction at the following positions in the interacting lanes:
# (1,): B(0, 4)
# (2,): B(0, 4)
# No alignment required.
# Lanes:
# ID: (0,), Name: a 0, Cardinality: 1:  [(Pos B(0, 0): Interaction A),(Pos B(0, 1): B),(Pos B(0, 2): C),(Pos B(0, 3): Interaction D)]
# ID: (1,), Name: b 0, Cardinality: 1:  [(Pos B(0, 0): Interaction A),(Pos B(0, 1): E),(Pos B(0, 2): F),(Pos B(0, 3): Interaction D),(Pos B(0, 4): Interaction J)]
# ID: (2,), Name: c 0, Cardinality: 1:  [(Pos B(0, 3): H),(Pos B(0, 4): Interaction J)]
#
# Involved Objects:
# {'b', 'a', 'c'}
#
# Interaction Points:
# Interaction Point: A at Pos: 0
# Interaction Point: D at Pos: 3
# Interaction Point: J at Pos: 4
# Frequency: 0.25
# -------------------
#
# Summarizing variant 3 of the process...
# ------------------------------------------
# Current Level: 1
# ----
# Summarizing Lanes: [0]
#
# Adding the common activity: A
# This is an interaction point: True
#
# Adding the common activity: C
# This is an interaction point: False
#
# Adding the common activity: D
# This is an interaction point: True
# ------------------------------------------
# Current Level: 2
# ----
# Summarizing Lanes: [2]
#
# Adding the common activity: A
# This is an interaction point: True
#
# Adding the common activity: G
# This is an interaction point: False
#
# Adding the common activity: D
# This is an interaction point: True
# ----
# Summarizing Lanes: [3]
#
# Adding the common activity: A
# This is an interaction point: True
#
# Adding the common activity: G
# This is an interaction point: False
#
# Adding the common activity: D
# This is an interaction point: True
# ----
# Redundancy found, pruning subtree!
#
#
# ------------------------------------------
# Current Level: 2
# ----
# Summarizing Lanes: [3]
#
# Adding the common activity: A
# This is an interaction point: True
#
# Adding the common activity: G
# This is an interaction point: False
#
# Adding the common activity: D
# This is an interaction point: True
# ----
# Summarizing Lanes: [2, 1]
#
# Adding the common activity: A
# This is an interaction point: True
#
#
# Applying a pattern to the elements:
# [<Super_Variant_Definition.CommonConstruct object at 0x1210944d0>]
# [<Super_Variant_Definition.CommonConstruct object at 0x121096a50>, <Super_Variant_Definition.CommonConstruct object at 0x121097050>]
#
# Adding a choice element between the following sequences.
# (Pos R(0, B(0, 1)): G)
# ----------
# (Pos R(0, B(1, 1)): E)
# (Pos R(0, B(1, 2)): F)
# ----------
#
# Adding the common activity: D
# This is an interaction point: True
# ----
# Redundancy found, pruning subtree!
#
#
# ------------------------------------------
# Current Level: 2
# ----
# Summarizing Lanes: [2, 3]
#
# Adding the common activity: A
# This is an interaction point: True
#
# Adding the common activity: G
# This is an interaction point: False
#
# Adding the common activity: D
# This is an interaction point: True
# ----
# Summarizing Lanes: [1]
#
# Adding the common activity: A
# This is an interaction point: True
#
# Adding the common activity: E
# This is an interaction point: False
#
# Adding the common activity: F
# This is an interaction point: False
#
# Adding the common activity: D
# This is an interaction point: True
# ----
# Leaf node reached!
#
#
# ------------------------------------------
# Current Level: 2
# ----
# Summarizing Lanes: [2]
#
# Adding the common activity: A
# This is an interaction point: True
#
# Adding the common activity: G
# This is an interaction point: False
#
# Adding the common activity: D
# This is an interaction point: True
# ----
# Summarizing Lanes: [3, 1]
#
# Adding the common activity: A
# This is an interaction point: True
#
#
# Applying a pattern to the elements:
# [<Super_Variant_Definition.CommonConstruct object at 0x1210c1590>]
# [<Super_Variant_Definition.CommonConstruct object at 0x1210a0450>, <Super_Variant_Definition.CommonConstruct object at 0x1210a0690>]
#
# Adding a choice element between the following sequences.
# (Pos R(0, B(0, 1)): G)
# ----------
# (Pos R(0, B(1, 1)): E)
# (Pos R(0, B(1, 2)): F)
# ----------
#
# Adding the common activity: D
# This is an interaction point: True
# ----
# Redundancy found, pruning subtree!
#
#
# ------------------------------------------
# Current Level: 2
# ----
# Summarizing Lanes: [2, 3, 1]
#
# Adding the common activity: A
# This is an interaction point: True
#
#
# Applying a pattern to the elements:
# [<Super_Variant_Definition.CommonConstruct object at 0x1210c2490>]
# [<Super_Variant_Definition.CommonConstruct object at 0x1210c21d0>]
# [<Super_Variant_Definition.CommonConstruct object at 0x1210a12d0>, <Super_Variant_Definition.CommonConstruct object at 0x1210a0910>]
#
# Adding a choice element between the following sequences.
# (Pos R(0, B(0, 1)): G)
# ----------
# (Pos R(0, B(1, 1)): E)
# (Pos R(0, B(1, 2)): F)
# ----------
#
# Adding the common activity: D
# This is an interaction point: True
# ----
# Leaf node reached!
#
#
#
#
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 0)
# (2, 3): B(0, 0)
# (1,): B(0, 0)
# No alignment required.
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 0)
# (2, 3): B(0, 0)
# (1,): B(0, 0)
# No alignment required.
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 2)
# (2, 3): B(0, 2)
# (1,): B(0, 3)
# We have shifted lane a i by 1 starting from the element at the position B(0, 2).
# We have shifted lane b i by 1 starting from the element at the position B(0, 2).
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 3)
# (2, 3): B(0, 3)
# (1,): B(0, 3)
# No alignment required.
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 0)
# (2, 3): B(0, 0)
# (1,): B(0, 0)
# No alignment required.
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 0)
# (2, 3): B(0, 0)
# (1,): B(0, 0)
# No alignment required.
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 3)
# (2, 3): B(0, 3)
# (1,): B(0, 3)
# No alignment required.
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 3)
# (2, 3): B(0, 3)
# (1,): B(0, 3)
# No alignment required.
# Lanes:
# ID: (0,), Name: a 0, Cardinality: 1:  [(Pos B(0, 0): Interaction A),(Pos B(0, 2): C),(Pos B(0, 3): Interaction D)]
# ID: (1,), Name: b 0, Cardinality: 1:  [(Pos B(0, 0): Interaction A),(Pos B(0, 1): E),(Pos B(0, 2): F),(Pos B(0, 3): Interaction D)]
# ID: (2, 3), Name: b 1, Cardinality: n:  [(Pos B(0, 0): Interaction A),(Pos B(0, 2): G),(Pos B(0, 3): Interaction D)]
#
# Involved Objects:
# {'b', 'a'}
#
# Interaction Points:
# Interaction Point: A at Pos: 0
# Interaction Point: A at Pos: 0
# Interaction Point: D at Pos: 3
# Interaction Point: D at Pos: 3
# Frequency: 0.25
# -------------------
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 0)
# (2, 3, 1): B(0, 0)
# No alignment required.
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 0)
# (2, 3, 1): B(0, 0)
# No alignment required.
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 0)
# (2, 3, 1): B(0, 0)
# No alignment required.
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 2)
# (2, 3, 1): B(0, 3)
# We have shifted lane a i by 1 starting from the element at the position B(0, 2).
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 3)
# (2, 3, 1): B(0, 3)
# No alignment required.
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 3)
# (2, 3, 1): B(0, 3)
# No alignment required.
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 0)
# (2, 3, 1): B(0, 0)
# No alignment required.
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 0)
# (2, 3, 1): B(0, 0)
# No alignment required.
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 0)
# (2, 3, 1): B(0, 0)
# No alignment required.
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 3)
# (2, 3, 1): B(0, 3)
# No alignment required.
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 3)
# (2, 3, 1): B(0, 3)
# No alignment required.
# We have an interaction at the following positions in the interacting lanes:
# (0,): B(0, 3)
# (2, 3, 1): B(0, 3)
# No alignment required.
# Lanes:
# ID: (0,), Name: a 0, Cardinality: 1:  [(Pos B(0, 0): Interaction A),(Pos B(0, 2): C),(Pos B(0, 3): Interaction D)]
# ID: (2, 3, 1), Name: b 0, Cardinality: n:  [(Pos B(0, 0): Interaction A),(Pos: B(0, 1) - B(0, 2): Choices (ID: 0, Name: Option 0, Cardinality: n:  [(Pos R(0, B(0, 2)): G)], ID: 1, Name: Option 1, Cardinality: 1:  [(Pos R(0, B(1, 1)): E),(Pos R(0, B(1, 2)): F)]),(Pos B(0, 3): Interaction D)]
#
# Involved Objects:
# {'b', 'a'}
#
# Interaction Points:
# Interaction Point: A at Pos: 0
# Interaction Point: A at Pos: 0
# Interaction Point: A at Pos: 0
# Interaction Point: D at Pos: 3
# Interaction Point: D at Pos: 3
# Interaction Point: D at Pos: 3
# Frequency: 0.25
# -------------------
# All Summarizations:
#  (0, ('a 0: CAR 1: IP[0:0, A] CO[2:2, C] IP[3:3, D] b 0: CAR 1: IP[0:0, A] CO[2:2, G] IP[3:3, D] IP[4:4, J] b 1: CAR n: IP[0:0, A] CO[1:1, E] CO[2:2, F] IP[3:3, D] c 0: CAR 1: CO[3:3, H] IP[4:4, J] - IP[0,[a 0, b 0, b 1]] IP[0,[a 0, b 0, b 1]] IP[3,[a 0, b 0, b 1]] IP[3,[a 0, b 0, b 1]] IP[4,[b 0, c 0]] ', [<Super_Variant_Definition.SummarizedVariant object at 0x1210589d0>]))
#
# Per Variant Dict:
#  [(0, ('a 0: CAR 1: IP[0:0, A] CO[2:2, C] IP[3:3, D] b 0: CAR 1: IP[0:0, A] CO[2:2, G] IP[3:3, D] IP[4:4, J] b 1: CAR n: IP[0:0, A] CO[1:1, E] CO[2:2, F] IP[3:3, D] c 0: CAR 1: CO[3:3, H] IP[4:4, J] - IP[0,[a 0, b 0, b 1]] IP[0,[a 0, b 0, b 1]] IP[3,[a 0, b 0, b 1]] IP[3,[a 0, b 0, b 1]] IP[4,[b 0, c 0]] ', [<Super_Variant_Definition.SummarizedVariant object at 0x1210589d0>]))]
#
# Per Encoding Dict:
#  {'a 0: CAR 1: IP[0:0, A] CO[2:2, C] IP[3:3, D] b 0: CAR 1: IP[0:0, A] CO[2:2, G] IP[3:3, D] IP[4:4, J] b 1: CAR n: IP[0:0, A] CO[1:1, E] CO[2:2, F] IP[3:3, D] c 0: CAR 1: CO[3:3, H] IP[4:4, J] - IP[0,[a 0, b 0, b 1]] IP[0,[a 0, b 0, b 1]] IP[3,[a 0, b 0, b 1]] IP[3,[a 0, b 0, b 1]] IP[4,[b 0, c 0]] ': ([0], [<Super_Variant_Definition.SummarizedVariant object at 0x1210589d0>]), 'a 0: CAR 1: IP[0:0, A] CO[2:2, C] IP[3:3, D] b 0: CAR 1: IP[0:0, A] IP[3:3, D] IP[4:4, J] b 1: CAR n: IP[0:0, A] CO[1:1, E] CO[2:2, F] IP[3:3, D] c 0: CAR 1: CO[3:3, H] IP[4:4, J] - IP[0,[a 0, b 0, b 1]] IP[0,[a 0, b 0, b 1]] IP[3,[a 0, b 0, b 1]] IP[3,[a 0, b 0, b 1]] IP[4,[b 0, c 0]] ': ([1], [<Super_Variant_Definition.SummarizedVariant object at 0x12105cc90>]), 'a 0: CAR 1: IP[0:0, A] CO[1:1, B] CO[2:2, C] IP[3:3, D] b 0: CAR 1: IP[0:0, A] CO[1:1, E] CO[2:2, F] IP[3:3, D] IP[4:4, J] c 0: CAR 1: CO[3:3, H] IP[4:4, J] - IP[0,[a 0, b 0]] IP[3,[a 0, b 0]] IP[4,[b 0, c 0]] ': ([2], [<Super_Variant_Definition.SummarizedVariant object at 0x121052c50>]), 'a 0: CAR 1: IP[0:0, A] CO[2:2, C] IP[3:3, D] b 0: CAR 1: IP[0:0, A] CO[1:1, E] CO[2:2, F] IP[3:3, D] b 1: CAR n: IP[0:0, A] CO[2:2, G] IP[3:3, D] - IP[0,[a 0, b 0, b 1]] IP[0,[a 0, b 0, b 1]] IP[3,[a 0, b 0, b 1]] IP[3,[a 0, b 0, b 1]] ': ([3], [<Super_Variant_Definition.SummarizedVariant object at 0x1210a1290>]), 'a 0: CAR 1: IP[0:0, A] CO[2:2, C] IP[3:3, D] b 0: CAR n: IP[0:0, A] CH[1:2, [Option 0 CO[1:1, E] CO[2:2, F], Option 1 CO[2:2, G]]] IP[3:3, D] - IP[0,[a 0, b 0]] IP[0,[a 0, b 0]] IP[0,[a 0, b 0]] IP[3,[a 0, b 0]] IP[3,[a 0, b 0]] IP[3,[a 0, b 0]] ': ([3], [<Super_Variant_Definition.SummarizedVariant object at 0x12105c290>])}
#   0%|          | 0/4 [00:00<?, ?it/s]
#
# Summarizing variant 0 of the process...
#
# Summarizing variant 1 of the process...
#
# Summarizing variant 2 of the process...
#
# Summarizing variant 3 of the process...
# Restricted license - for non-production use only - expires 2026-11-23
# INFO:gurobipy:Restricted license - for non-production use only - expires 2026-11-23
#  Objective value: 4
#
#
#  Variable values:
#
# 0: 1.0
# 1: 1.0
# 2: 1.0
# 3: 1.0
# 4: 0.0
# -----------------------------
# 4/5unique summarizations have been selected for the Between-Lane Summarization.
# Intra Variant Summarizations:
#  Super Variant (0,)
# Lanes:
# ID: (0,), Name: a 0, Cardinality: 1:  [(Pos B(0, 0): Interaction A),(Pos B(0, 2): C),(Pos B(0, 3): Interaction D)]
# ID: (2,), Name: b 0, Cardinality: 1:  [(Pos B(0, 0): Interaction A),(Pos B(0, 2): G),(Pos B(0, 3): Interaction D),(Pos B(0, 4): Interaction J)]
# ID: (1, 3), Name: b 1, Cardinality: n:  [(Pos B(0, 0): Interaction A),(Pos B(0, 1): E),(Pos B(0, 2): F),(Pos B(0, 3): Interaction D)]
# ID: (4,), Name: c 0, Cardinality: 1:  [(Pos B(0, 3): H),(Pos B(0, 4): Interaction J)]
#
# Involved Objects:
# {'b', 'a', 'c'}
#
# Interaction Points:
# Interaction Point: A at Pos: 0
# Interaction Point: A at Pos: 0
# Interaction Point: D at Pos: 3
# Interaction Point: D at Pos: 3
# Interaction Point: J at Pos: 4
# Frequency: 0.25

# %%
first = all_summarizations[3]
SVV.visualize_super_variant(intra_variant_summarizations[0])

superVarNr = first[0]
superVarStr = first[1][0]
superVarRef = first[1][1]

print("Super Variant Number: ", superVarNr)
print("Super Variant String:\n", superVarStr)
# Out:
# Super Variant Number:  3
# Super Variant String:
#  a 0: CAR 1: IP[0:0, A] CO[2:2, C] IP[3:3, D] b 0: CAR 1: IP[0:0, A] CO[1:1, E] CO[2:2, F] IP[3:3, D] b 1: CAR n: IP[0:0, A] CO[2:2, G] IP[3:3, D] - IP[0,[a 0, b 0, b 1]] IP[0,[a 0, b 0, b 1]] IP[3,[a 0, b 0, b 1]] IP[3,[a 0, b 0, b 1]]

# %% [markdown]
# @SuperLane.encode_lexicographically()
#
# a 0 -> Lane a, instance 0
#
# CAR 1 -> Lane instance is executed exactly once
#
# Constructs: -> [startIndex:EndIndex]
# - IP = Interaction Point
# - CO = CommonConstruct / "Plain Activity"
# - CH = ChoiceConstruct
# - OP = OptionalConstruct

# %% [markdown]
# # Inter-Variant Summarization

# %%
# MODE 1 - Frequency Distribution and No Nested Structures
IEVG.NESTED_STRUCTURES = False
initial_super_variants = intra_variant_summarizations

# Generating 3 hierarchies from the initial super variants with uniform frequency distribution
hierarchies, final_super_variants = IEVG.generate_super_variant_hierarchy(
    initial_super_variants, 3, frequency_distribution_type=IEVG.Distribution.UNIFORM)

print("Hierarchies", hierarchies, "\n\n\n")
print("Final super variants", final_super_variants, "\n\n\n")

# Visualizing each hierarchy top-down
for final_super_variant in final_super_variants[0]:
    SVH.explore_hierarchy_top_down(final_super_variant)

print_hierarchy_costs(hierarchies)
# Out:
# Evaluating the decision of matching lane (1,) of Super Variant 1 with the lane (1,) of Super Variant 2.
# Not propagating.
# This is so far the most optimal decision.
# Evaluating the decision of matching lane (1,) of Super Variant 1 with the lane (3, 2) of Super Variant 2.
# Not propagating.
# ------------------------------------
# Evaluating the decision of matching lane (0,) of Super Variant 1 with the lane (0,) of Super Variant 2.
# Propagating.
# Propagating the last decision among [] and [<Super_Variant_Definition.SuperLane object at 0x1218ced50>].
# Empty. The rest is optional.
# Lane (3, 2) of Super Variant 2 has no matching partner and is optional.
# Propagating.
# Propagating the last decision among [] and [].
# Empty. The rest is optional.
# This is so far the most optimal decision.
# ------------------------------------
# Evaluating the decision of matching lane (1,) of Super Variant 1 with the lane (1,) of Super Variant 2.
# Not propagating.
# This is so far the most optimal decision.
# Evaluating the decision of matching lane (1,) of Super Variant 1 with the lane (3, 2) of Super Variant 2.
# Not propagating.
# ------------------------------------
# Evaluating the decision of matching lane (0,) of Super Variant 1 with the lane (0,) of Super Variant 2.
# Propagating.
# Propagating the last decision among [] and [<Super_Variant_Definition.SuperLane object at 0x12192d350>].
# Empty. The rest is optional.
# Lane (3, 2) of Super Variant 2 has no matching partner and is optional.
# Propagating.
# Propagating the last decision among [] and [].
# Empty. The rest is optional.
# This is so far the most optimal decision.
# ------------------------------------
# Evaluating the decision of matching lane (0,) of Super Variant 1 with the lane (0,) of Super Variant 2.
# Not propagating.
# This is so far the most optimal decision.
# ------------------------------------
# Empty. The rest is optional.
# Lane (2,) of Super Variant 2 has no matching partner and is optional.
# Hierarchies [[{0: ([(<Super_Variant_Definition.SuperVariant object at 0x1210e2490>, None, None)], 0)}, {0: ([(<Super_Variant_Definition.SuperVariant object at 0x1210e1690>, None, None)], 0)}, {1: ([(<Super_Variant_Definition.SuperVariant object at 0x121959010>, (<Super_Variant_Definition.SuperVariant object at 0x1218cded0>, None, None), (<Super_Variant_Definition.SuperVariant object at 0x12192a450>, None, None))], 7), 0: ([(<Super_Variant_Definition.SuperVariant object at 0x1210e1210>, None, None), (<Super_Variant_Definition.SuperVariant object at 0x121357610>, None, None)], 0)}]]
#
#
#
# Final super variants [[(<Super_Variant_Definition.SuperVariant object at 0x1210e2490>, None, None), (<Super_Variant_Definition.SuperVariant object at 0x1210e1690>, None, None), (<Super_Variant_Definition.SuperVariant object at 0x121959010>, (<Super_Variant_Definition.SuperVariant object at 0x1218cded0>, None, None), (<Super_Variant_Definition.SuperVariant object at 0x12192a450>, None, None))]]
# Cost for hierarchy 0: 7

# %%
print(hierarchies[0], str([0]))
SVH.explore_hierarchy_top_down(final_super_variants[0][0])
# Out:
# [{0: ([(<Super_Variant_Definition.SuperVariant object at 0x1210e2490>, None, None)], 0)}, {0: ([(<Super_Variant_Definition.SuperVariant object at 0x1210e1690>, None, None)], 0)}, {1: ([(<Super_Variant_Definition.SuperVariant object at 0x121959010>, (<Super_Variant_Definition.SuperVariant object at 0x1218cded0>, None, None), (<Super_Variant_Definition.SuperVariant object at 0x12192a450>, None, None))], 7), 0: ([(<Super_Variant_Definition.SuperVariant object at 0x1210e1210>, None, None), (<Super_Variant_Definition.SuperVariant object at 0x121357610>, None, None)], 0)}] [0]

# %%
print(hierarchies[0][0])
# Out:
# {0: ([(<Super_Variant_Definition.SuperVariant object at 0x1210e2490>, None, None)], 0)}
