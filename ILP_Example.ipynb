# %% [markdown]
# # Students
# **Emilie Hastrup-Kiil** - 379455
#
# **Julian Staab** - 378595

# %%
import numpy as np
import pandas as pd
from gurobipy import *

# For progress bar
# Instead of writing...
# > for i in some_list:
# You can write....
# > for i in tqdm(some_list):
# And you will get a very nice progress bar. This is very nice for 
# for-loops that run a long time, like running an optimization model for 
# many timesteps :)
from tqdm.auto import tqdm, trange  

# Plotting libaries - Feel free to use any others of your choice
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.style as style
style.use('fivethirtyeight')

# Enable high resolution plots
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')

# %% [markdown]
# # HINT
# I recommend that you read through this notebook once *before* you start coding - you can do it all on your own but if you adhere to the structure that we hint at in this notebook, it might be easier for you

# %% [markdown]
# ## Reading data
# This data is pretty clean but there are some surprises... I recommend that you re-index the dataframe with a [datetime-index](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DatetimeIndex.html) since they have some very convienient attributes and methods which you will need (unless you want to put more effort into this).
# So for example the entries "01-01-2019", "00 - 01" should be changed so that this row has a datetime index "2019-01-01 00:00:00"

# %%
import datetime
def read_ElspotPrices(filename):
    
    # Read file, exlude first two rows of data set
    df = pd.read_html(filename, decimal=',', thousands='.', header=2)[0]
    df.rename( columns={'Unnamed: 0':''}, inplace=True )
    
    # Format hours and datetime correctly and combine in the index column
    for index, row in df.iterrows():
        df.loc[index, 'Hours'] = datetime.timedelta(hours=int(row['Hours'].split("-")[1])-1)
        df.loc[index, ''] = datetime.datetime.strptime(row[''], '%d-%m-%Y')
        df.loc[index, ''] = df.loc[index, 'Hours'] + df.loc[index, '']
        
    # Set intex column and remove hours column
    df = df.set_index('')
    df = df.drop(['Hours'], axis=1)
    
    return df # Returning a pandas dataframe

# %%
path = "elspot-prices_2019_hourly_eur.xls"
df = read_ElspotPrices(path) # You can rename variables
df.head()
# Out:
#                        SYS    SE1    SE2    SE3    SE4     FI    DK1    DK2  \
#
# 2019-01-01 00:00:00  44.55  28.32  28.32  28.32  28.32  28.32  28.32  28.32
# 2019-01-01 01:00:00  44.07  10.07  10.07  10.07  10.07  10.07  10.07  10.07
# 2019-01-01 02:00:00  41.12  10.03  10.03  10.03  10.03  10.03  -4.08  -4.08
# 2019-01-01 03:00:00  38.88   4.56   4.56   4.56   4.56   4.56  -9.91  -9.91
# 2019-01-01 04:00:00  35.70   4.83   4.83   4.83   4.83   4.83  -7.41  -7.41
#
#                       Oslo  Kr.sand  ...  AT  AT.1  BE  BE.1  DE-LU  DE-LU.1  \
#                                      ...
# 2019-01-01 00:00:00  48.77    48.77  ... NaN   NaN NaN   NaN    NaN      NaN
# 2019-01-01 01:00:00  49.25    49.25  ... NaN   NaN NaN   NaN    NaN      NaN
# 2019-01-01 02:00:00  49.17    49.17  ... NaN   NaN NaN   NaN    NaN      NaN
# 2019-01-01 03:00:00  48.37    48.37  ... NaN   NaN NaN   NaN    NaN      NaN
# 2019-01-01 04:00:00  47.19    47.19  ... NaN   NaN NaN   NaN    NaN      NaN
#
#                      FR  FR.1  NL  NL.1
#
# 2019-01-01 00:00:00 NaN   NaN NaN   NaN
# 2019-01-01 01:00:00 NaN   NaN NaN   NaN
# 2019-01-01 02:00:00 NaN   NaN NaN   NaN
# 2019-01-01 03:00:00 NaN   NaN NaN   NaN
# 2019-01-01 04:00:00 NaN   NaN NaN   NaN
#
# [5 rows x 30 columns]

# %% [markdown]
# #### Daylight savings time
# The data from Elspot contains one hour twice and one hour is missing, thanks to daylight savings time. You have to convert the data so that the timezone is without daylight savings (so no hours exist twice or are missing).
# You should also convert the data to UTC+0. The Nordpool headquarters are in norway (CET with summer time, so during the summer they have UTC+2 and during winter UTC+1).
# Below an example of the day light savings switch and how it should look like after you converted the time.
# Hint: You can use pandas functions for this, it can be done in three lines of code

# %%
# Find the day light savings switch with duplicated datetime (clocks turned back for 1 hour)
# You can remove this cell if you want
timediffs = pd.Series(df.index).diff() # Calculate time difference between indices
daylight_idx = timediffs[timediffs == pd.Timedelta(0)].idxmax() #  Find row with no time-difference 
df[daylight_idx-2:daylight_idx+2] # Show the rows surrounding this row
# Out:
#                        SYS    SE1    SE2    SE3    SE4     FI    DK1    DK2  \
#
# 2019-10-27 01:00:00  33.84  31.68  31.68  31.68  31.68  31.68  27.11  27.11
# 2019-10-27 02:00:00  33.43  31.46  31.46  31.46  31.46  31.46   9.04   9.04
# 2019-10-27 02:00:00  33.18  31.49  31.49  31.49  31.49  31.49   0.05   0.05
# 2019-10-27 03:00:00  33.05  31.12  31.12  31.12  31.12  31.12   0.12   0.12
#
#                       Oslo  Kr.sand  ...  AT   AT.1  BE   BE.1  DE-LU  \
#                                      ...
# 2019-10-27 01:00:00  37.12    37.12  ... NaN  32.01 NaN  26.30    NaN
# 2019-10-27 02:00:00  37.11    37.11  ... NaN  31.07 NaN  14.25    NaN
# 2019-10-27 02:00:00  37.11    37.11  ... NaN  31.05 NaN  25.81    NaN
# 2019-10-27 03:00:00  37.08    37.08  ... NaN  31.04 NaN  22.76    NaN
#
#                      DE-LU.1  FR   FR.1  NL   NL.1
#
# 2019-10-27 01:00:00   -34.57 NaN  27.30 NaN  27.11
# 2019-10-27 02:00:00   -29.97 NaN  21.13 NaN  25.00
# 2019-10-27 02:00:00    -9.97 NaN  11.58 NaN  25.70
# 2019-10-27 03:00:00     0.12 NaN  14.03 NaN  22.86
#
# [4 rows x 30 columns]

# %%
# Store the timestamps of the change points of daylight saving time
daylight_saving_start_idx = df[daylight_idx:daylight_idx+1].index
daylight_saving_end_idx = df.index[np.isnan(df.iloc[:, 0])]

# Mark each row as either within the daylight saving time or not
dst=[]
dst_ended = False
for index, row in df.iterrows():
    
    # During summer we don't have daylight saving time
    if index >= daylight_saving_end_idx and index < daylight_saving_start_idx:
        dst.append(False)
        
    # One of the duplicate timestamps is within the daylight saving time and the other not
    elif index == daylight_saving_start_idx and not dst_ended:
        dst.append(True)
        dst_ended = True
    
    # During winter we hav daylight saving time
    elif index == daylight_saving_start_idx and dst_ended:
        dst.append(False)
        dst_ended = True
    else:
        dst.append(True)

# %%
def removeDaylightSavings(df):
    
    # Indicate the current time zone and daylight saving time
    df.index = df.index.tz_localize('CET', ambiguous=dst, nonexistent='shift_forward')
    
    # Convert to neutral time zone
    df.index = df.index.tz_convert(None) 
    
    return df

# %%
df = removeDaylightSavings(df)
df[daylight_idx-2:daylight_idx+2]
# Out:
#                        SYS    SE1    SE2    SE3    SE4     FI    DK1    DK2  \
#
# 2019-10-26 23:00:00  33.84  31.68  31.68  31.68  31.68  31.68  27.11  27.11
# 2019-10-27 00:00:00  33.43  31.46  31.46  31.46  31.46  31.46   9.04   9.04
# 2019-10-27 01:00:00  33.18  31.49  31.49  31.49  31.49  31.49   0.05   0.05
# 2019-10-27 02:00:00  33.05  31.12  31.12  31.12  31.12  31.12   0.12   0.12
#
#                       Oslo  Kr.sand  ...  AT   AT.1  BE   BE.1  DE-LU  \
#                                      ...
# 2019-10-26 23:00:00  37.12    37.12  ... NaN  32.01 NaN  26.30    NaN
# 2019-10-27 00:00:00  37.11    37.11  ... NaN  31.07 NaN  14.25    NaN
# 2019-10-27 01:00:00  37.11    37.11  ... NaN  31.05 NaN  25.81    NaN
# 2019-10-27 02:00:00  37.08    37.08  ... NaN  31.04 NaN  22.76    NaN
#
#                      DE-LU.1  FR   FR.1  NL   NL.1
#
# 2019-10-26 23:00:00   -34.57 NaN  27.30 NaN  27.11
# 2019-10-27 00:00:00   -29.97 NaN  21.13 NaN  25.00
# 2019-10-27 01:00:00    -9.97 NaN  11.58 NaN  25.70
# 2019-10-27 02:00:00     0.12 NaN  14.03 NaN  22.86
#
# [4 rows x 30 columns]

# %% [markdown]
# This is how your data should be formated that you use as input for the "prediction generator":
# * pd.Series() containing the prices for your market area
# * index should be of type datetime -> This will make it much easier to create your plots later

# %%
example = df["SE1"]
example
# Out:
# 2018-12-31 23:00:00    28.32
# 2019-01-01 00:00:00    10.07
# 2019-01-01 01:00:00    10.03
# 2019-01-01 02:00:00     4.56
# 2019-01-01 03:00:00     4.83
#                        ...
# 2019-12-31 18:00:00    32.37
# 2019-12-31 19:00:00    31.23
# 2019-12-31 20:00:00    31.33
# 2019-12-31 21:00:00    31.46
# 2019-12-30 22:00:00    30.83
# Name: SE1, Length: 8761, dtype: float64

# %%
df.index
# Out:
# DatetimeIndex(['2018-12-31 23:00:00', '2019-01-01 00:00:00',
#                '2019-01-01 01:00:00', '2019-01-01 02:00:00',
#                '2019-01-01 03:00:00', '2019-01-01 04:00:00',
#                '2019-01-01 05:00:00', '2019-01-01 06:00:00',
#                '2019-01-01 07:00:00', '2019-01-01 08:00:00',
#                ...
#                '2019-12-31 13:00:00', '2019-12-31 14:00:00',
#                '2019-12-31 15:00:00', '2019-12-31 16:00:00',
#                '2019-12-31 17:00:00', '2019-12-31 18:00:00',
#                '2019-12-31 19:00:00', '2019-12-31 20:00:00',
#                '2019-12-31 21:00:00', '2019-12-30 22:00:00'],
#               dtype='datetime64[ns]', name='', length=8761, freq=None)

# %% [markdown]
# ## "Predicting" future prices
# Since this is not a data science course, we will compare two very simple "prediction" methods:
# 1) We perfectly know future prices
# 2) Assume price will be the same as last weeks price at the same time
#
# If you want, you can also implement more elaborate prediction methods - you may be able to beat the results from 2) but you should not be able to beat 1)
# In case you implement another predictor, you should obviously only use the prices up to t-1 to predict prices for t to t + n :)

# %%
# You do not have to touch this code
class PredictionGenerator():
    def __init__(self, timeseries, method="perfect"):
        self.setMethod(method)
        self.df = timeseries

    # If you use more elaborate prediction methods, you might have to fit a model to the data
    # Implementing another prediction method will not better your grade, so ignore this if you want.
    def fit(self, end_date):
        pass

    # "Predict" prices for some date range defined by a start date and a number of hours
    def predict(self, start_date, nhours):
        dates = pd.date_range(
            start=start_date,
            periods=nhours,
            freq="H")

        if self.method == "Perfect":
            if dates.max() not in self.df.index: # check if prices known
                raise Exception(("You can not forecast the *future* perfectly "
                                 "out of sample! Some of the dates requested "
                                 "are not in the given dataset."))
            result = self.df.loc[dates]  # the actual observed prices
        elif self.method == "SameHourLastWeek":
            min_date = (dates.min() + pd.DateOffset(hours=-7*24))
            max_date = (dates.max() + pd.DateOffset(hours=-7*24))
            if (min_date not in self.df.index) or (max_date not in self.df.index):
                raise Exception(("For some of the dates you tried to predict, "
                                 "there is no data from the week before available."))
            # Last weeks prices
            result = self.df.loc[dates + pd.DateOffset(hours=-7*24)]
            result.index = dates
            
        return result

    
    # Set method if known, otherwise raise exception
    def setMethod(self, method):
        methods = ["Perfect", "SameHourLastWeek"]
        if method not in methods:
            raise Exception(f"Method passed({method}) is not in ["
                            + ", ".join(methods) + "]")
        self.method = method

# %%
# Example how to use:
# Create predictor
prediction_method = "SameHourLastWeek" # methods = ["Perfect", "SameHourLastWeek"]
prices = df["SE1"] # All prices that we have for the market area of interest as a Series
predictor = PredictionGenerator(prices, method=prediction_method)
# "Predict" prices for some time frame
t_start = pd.Timestamp("2019-10-22 00:00:00")
predicted_prices = predictor.predict(t_start, 10) # returns a series of "predicted" prices
                                                  # for the 10 hours starting on t_start

# %% [markdown]
# ## The gurobi model

# %%
def solve(prices,                
          Pmax,
          Emax,
          E0,
          print_result=False):
    
    # Create model
    model = Model("Aluminum DSM")
    model.modelSense = GRB.MINIMIZE
    
    #--------------------------------------------------------------------------------
    
    # Flag decides whether output is printed
    if not print_result:
        model.setParam('OutputFlag', False)
    
    P={}
    E={}
    # Create variables for power and energy deviations from nominal
    for t in prices.index:
        P[t] = model.addVar(lb=-Pmax,name="P%s" % t)
        E[t] = model.addVar(lb=-Emax,name="E%s" % t)
        
    # Make variables visible to model  
    model.update()
    
    #--------------------------------------------------------------------------------
    
    # Add constraints such that we cannot exeed any limits given by maximum power and energy limit
    for t in prices.index:
        model.addConstr(-Pmax <= P[t])
        model.addConstr(P[t] <= Pmax)   
        model.addConstr(-Emax <= E[t])
        model.addConstr(E[t] <= Emax)
    
    tau = prices.index[0]
    t_horizon = len(prices)
    t_minusOne = prices.index[0]
    
    # Add constraint to ensure continuity between timesteps
    for t in prices.index:
        if t != tau:
            model.addConstr(E[t] == E[t_minusOne] + P[t])
        t_minusOne = t
        
    # Add constraint to define energy difference at start and end
    model.addConstr(E[tau] == E0 + P[tau])
    model.addConstr(E[prices.index[t_horizon-1]] == 0)
    
    #--------------------------------------------------------------------------------
    
    # Set objective to minimizing the overall price and optimize
    model.setObjective(sum(prices[t]*P[t] for t in prices.index))
    model.optimize()
    
    return model

# %% [markdown]
# # Running your scenario
# The following cell is just to show you how to use tqdm for a progress bar, you can delete that cell and write the code to run the scenario how you want :)

# %%
def runScenario(historic_prices,             # Historic electricty prices
                E0, Emax, Pmax,              # Plant parameters
                prediction_method,           # Prediction settings
                t_start, t_end, t_horizon):  # Simulation times

    # Initialize everything
    data = []
    P = {}
    E = {}
    
    for t in tqdm(pd.date_range(t_start, t_end, freq="H")):
        pass
    
        # Predict prices with predictor and prepare data for the model
        predictor = PredictionGenerator(historic_prices, method=prediction_method)
        prices = predictor.predict(t, t_horizon)
        prices[t] = historic_prices[t]
        
        # Run model
        model = solve(prices,Pmax,Emax,E0)
        
        # Save results from current timestep
        P[t] = model.getVarByName("P%s" % t).x
        E[t] = model.getVarByName("E%s" % t).x
        
        # - Set E0 based on optimization results for current time step
        E0=E0+P[t]
        
        # Compute earnings for later visualizations
        earnings = -historic_prices[t]*P[t]
        
        # Store and write current results to console
        data.append([t, P[t], E[t], earnings])
        tqdm.write("%s: P = %s, E = %s, earnings = %s" % (t, P[t],  E[t], earnings))
        
    # Convert results to dataframe
    results = pd.DataFrame(data, columns=['Timeslot', 'Power', 'Energy', 'Earnings'])
    
    return results

# %%
# Get necessary data
market_area = "SE1"
historic_prices = df[market_area]

# Define Plant parameters
E0 = 0                                   # Energy difference at t = t_start
Pmax = 100                               # Maximum power deviation in MW
Emax = 48 * Pmax                         # Maximum energy deviation in MWh

# Define Simulation parameters
t_start = pd.Timestamp("2019-10-22 00:00:00") # Times are in UTC+0
t_end = pd.Timestamp("2019-12-22 00:00:00")  # Simulate two months of operation
t_horizon = 7*24                             # Time horizon for optimization (in h)

# %%
results_perfect = runScenario(historic_prices,E0,Emax,Pmax,"Perfect",t_start, t_end, t_horizon)
results_lastweek = runScenario(historic_prices,E0,Emax,Pmax,"SameHourLastWeek",t_start, t_end, t_horizon)
# Out:
#   0%|          | 0/1465 [00:00<?, ?it/s]
# Academic license - for non-commercial use only - expires 2022-06-20
# Using license file D:\Program\gurobi.lic
# 2019-10-22 00:00:00: P = 100.0, E = 100.0, earnings = -3381.0
# 2019-10-22 01:00:00: P = 100.0, E = 200.0, earnings = -3184.0
# 2019-10-22 02:00:00: P = 100.0, E = 300.0, earnings = -3369.0
# 2019-10-22 03:00:00: P = 100.0, E = 400.0, earnings = -3458.0
# 2019-10-22 04:00:00: P = 100.0, E = 500.0, earnings = -3571.0
# 2019-10-22 05:00:00: P = -100.0, E = 400.0, earnings = 3678.0
# 2019-10-22 06:00:00: P = -100.0, E = 300.0, earnings = 3721.0
# 2019-10-22 07:00:00: P = -100.0, E = 200.0, earnings = 3672.9999999999995
# 2019-10-22 08:00:00: P = -100.0, E = 100.0, earnings = 3643.0
# 2019-10-22 09:00:00: P = 100.0, E = 200.0, earnings = -3578.0
# 2019-10-22 10:00:00: P = 100.0, E = 300.0, earnings = -3552.0000000000005
# 2019-10-22 11:00:00: P = 100.0, E = 400.0, earnings = -3488.0000000000005
# 2019-10-22 12:00:00: P = 100.0, E = 500.0, earnings = -3465.9999999999995
# 2019-10-22 13:00:00: P = 100.0, E = 600.0, earnings = -3471.0
# 2019-10-22 14:00:00: P = 100.0, E = 700.0, earnings = -3489.0
# 2019-10-22 15:00:00: P = 100.0, E = 800.0, earnings = -3533.0
# 2019-10-22 16:00:00: P = 100.0, E = 900.0, earnings = -3565.0
# 2019-10-22 17:00:00: P = 100.0, E = 1000.0, earnings = -3536.9999999999995
# 2019-10-22 18:00:00: P = 100.0, E = 1100.0, earnings = -3415.0
# 2019-10-22 19:00:00: P = 100.0, E = 1200.0, earnings = -3202.0000000000005
# 2019-10-22 20:00:00: P = 100.0, E = 1300.0, earnings = -2025.0
# 2019-10-22 21:00:00: P = 100.0, E = 1400.0, earnings = -3445.0000000000005
# 2019-10-22 22:00:00: P = 100.0, E = 1500.0, earnings = -1616.0
# 2019-10-22 23:00:00: P = 100.0, E = 1600.0, earnings = -1695.0
# 2019-10-23 00:00:00: P = 100.0, E = 1700.0, earnings = -1705.9999999999998
# 2019-10-23 01:00:00: P = 100.0, E = 1800.0, earnings = -2457.0
# 2019-10-23 02:00:00: P = 100.0, E = 1900.0, earnings = -3039.0
# 2019-10-23 03:00:00: P = 100.0, E = 2000.0, earnings = -3492.0
# 2019-10-23 04:00:00: P = -100.0, E = 1900.0, earnings = 3806.0
# 2019-10-23 05:00:00: P = -100.0, E = 1800.0, earnings = 3934.0000000000005
# 2019-10-23 06:00:00: P = -100.0, E = 1700.0, earnings = 3922.9999999999995
# 2019-10-23 07:00:00: P = -100.0, E = 1600.0, earnings = 3918.0
# 2019-10-23 08:00:00: P = -100.0, E = 1500.0, earnings = 3928.0
# 2019-10-23 09:00:00: P = -100.0, E = 1400.0, earnings = 3899.0
# 2019-10-23 10:00:00: P = -100.0, E = 1300.0, earnings = 3879.0
# 2019-10-23 11:00:00: P = -100.0, E = 1200.0, earnings = 3819.0
# 2019-10-23 12:00:00: P = -100.0, E = 1100.0, earnings = 3811.9999999999995
# 2019-10-23 13:00:00: P = -100.0, E = 1000.0, earnings = 3838.0000000000005
# 2019-10-23 14:00:00: P = -100.0, E = 900.0, earnings = 3840.0
# 2019-10-23 15:00:00: P = -100.0, E = 800.0, earnings = 3897.9999999999995
# 2019-10-23 16:00:00: P = -100.0, E = 700.0, earnings = 3950.0
# 2019-10-23 17:00:00: P = -100.0, E = 600.0, earnings = 3954.0
# 2019-10-23 18:00:00: P = -100.0, E = 500.0, earnings = 3915.9999999999995
# 2019-10-23 19:00:00: P = -100.0, E = 400.0, earnings = 3822.0
# 2019-10-23 20:00:00: P = 0.0, E = 400.0, earnings = -0.0
# 2019-10-23 21:00:00: P = 100.0, E = 500.0, earnings = -3106.0
# 2019-10-23 22:00:00: P = 100.0, E = 600.0, earnings = -3422.9999999999995
# 2019-10-23 23:00:00: P = 100.0, E = 700.0, earnings = -3295.0000000000005
# 2019-10-24 00:00:00: P = 100.0, E = 800.0, earnings = -3219.0
# 2019-10-24 01:00:00: P = 100.0, E = 900.0, earnings = -3213.0000000000005
# 2019-10-24 02:00:00: P = 100.0, E = 1000.0, earnings = -3292.0
# 2019-10-24 03:00:00: P = 100.0, E = 1100.0, earnings = -3447.0
# 2019-10-24 04:00:00: P = -100.0, E = 1000.0, earnings = 3797.0
# 2019-10-24 05:00:00: P = -100.0, E = 900.0, earnings = 3982.0
# 2019-10-24 06:00:00: P = -100.0, E = 800.0, earnings = 4015.0
# 2019-10-24 07:00:00: P = -100.0, E = 700.0, earnings = 4010.0
# 2019-10-24 08:00:00: P = -100.0, E = 600.0, earnings = 4010.0
# 2019-10-24 09:00:00: P = -100.0, E = 500.0, earnings = 3996.0
# 2019-10-24 10:00:00: P = -100.0, E = 400.0, earnings = 3972.0
# 2019-10-24 11:00:00: P = -100.0, E = 300.0, earnings = 3954.0
# 2019-10-24 12:00:00: P = -100.0, E = 200.0, earnings = 3840.9999999999995
# 2019-10-24 13:00:00: P = -100.0, E = 100.0, earnings = 3769.0
# 2019-10-24 14:00:00: P = -100.0, E = 0.0, earnings = 3807.0
# 2019-10-24 15:00:00: P = -100.0, E = -100.0, earnings = 3931.0
# 2019-10-24 16:00:00: P = -100.0, E = -200.0, earnings = 3972.9999999999995
# 2019-10-24 17:00:00: P = -100.0, E = -300.0, earnings = 3947.0
# 2019-10-24 18:00:00: P = 100.0, E = -200.0, earnings = -3685.0
# 2019-10-24 19:00:00: P = 100.0, E = -100.0, earnings = -3565.0
# 2019-10-24 20:00:00: P = 100.0, E = 0.0, earnings = -3457.0
# 2019-10-24 21:00:00: P = 100.0, E = 100.0, earnings = -2551.0
# 2019-10-24 22:00:00: P = 100.0, E = 200.0, earnings = -3068.0
# 2019-10-24 23:00:00: P = 100.0, E = 300.0, earnings = -2829.0
# 2019-10-25 00:00:00: P = 100.0, E = 400.0, earnings = -2520.0
# 2019-10-25 01:00:00: P = 100.0, E = 500.0, earnings = -2442.0
# 2019-10-25 02:00:00: P = 100.0, E = 600.0, earnings = -2607.0
# 2019-10-25 03:00:00: P = 100.0, E = 700.0, earnings = -3240.0
# 2019-10-25 04:00:00: P = 100.0, E = 800.0, earnings = -3597.9999999999995
# 2019-10-25 05:00:00: P = -100.0, E = 700.0, earnings = 3882.0
# 2019-10-25 06:00:00: P = -100.0, E = 600.0, earnings = 3900.0
# 2019-10-25 07:00:00: P = -100.0, E = 500.0, earnings = 3892.0
# 2019-10-25 08:00:00: P = -100.0, E = 400.0, earnings = 3893.0
# 2019-10-25 09:00:00: P = -100.0, E = 300.0, earnings = 3849.0
# 2019-10-25 10:00:00: P = 100.0, E = 400.0, earnings = -3565.0
# 2019-10-25 11:00:00: P = 100.0, E = 500.0, earnings = -3607.0
# 2019-10-25 12:00:00: P = 100.0, E = 600.0, earnings = -3478.0
# 2019-10-25 13:00:00: P = 100.0, E = 700.0, earnings = -3533.0
# 2019-10-25 14:00:00: P = 100.0, E = 800.0, earnings = -3603.0
# 2019-10-25 15:00:00: P = 100.0, E = 900.0, earnings = -3718.0
# 2019-10-25 16:00:00: P = -100.0, E = 800.0, earnings = 3783.0
# 2019-10-25 17:00:00: P = -100.0, E = 700.0, earnings = 3760.0
# 2019-10-25 18:00:00: P = 100.0, E = 800.0, earnings = -3458.0
# 2019-10-25 19:00:00: P = 100.0, E = 900.0, earnings = -3321.0
# 2019-10-25 20:00:00: P = 100.0, E = 1000.0, earnings = -3035.0
# 2019-10-25 21:00:00: P = 100.0, E = 1100.0, earnings = -3272.0
# 2019-10-25 22:00:00: P = 100.0, E = 1200.0, earnings = -2354.0
# 2019-10-25 23:00:00: P = 100.0, E = 1300.0, earnings = -1884.0
# 2019-10-26 00:00:00: P = 100.0, E = 1400.0, earnings = -1989.0
# 2019-10-26 01:00:00: P = 100.0, E = 1500.0, earnings = -1578.0
# 2019-10-26 02:00:00: P = 100.0, E = 1600.0, earnings = -855.0000000000001
# 2019-10-26 03:00:00: P = 100.0, E = 1700.0, earnings = -1584.0
# 2019-10-26 04:00:00: P = 100.0, E = 1800.0, earnings = -1462.0
# 2019-10-26 05:00:00: P = 100.0, E = 1900.0, earnings = -2461.0
# 2019-10-26 06:00:00: P = 100.0, E = 2000.0, earnings = -2936.0
# 2019-10-26 07:00:00: P = 100.0, E = 2100.0, earnings = -3328.0
# 2019-10-26 08:00:00: P = 100.0, E = 2200.0, earnings = -3415.0
# 2019-10-26 09:00:00: P = 100.0, E = 2300.0, earnings = -3453.0
# 2019-10-26 10:00:00: P = 100.0, E = 2400.0, earnings = -3446.0
# 2019-10-26 11:00:00: P = 100.0, E = 2500.0, earnings = -3452.0000000000005
# 2019-10-26 12:00:00: P = 100.0, E = 2600.0, earnings = -3459.0000000000005
# 2019-10-26 13:00:00: P = 100.0, E = 2700.0, earnings = -3472.9999999999995
# 2019-10-26 14:00:00: P = 100.0, E = 2800.0, earnings = -3571.0
# 2019-10-26 15:00:00: P = 100.0, E = 2900.0, earnings = -3702.0000000000005
# 2019-10-26 16:00:00: P = -100.0, E = 2800.0, earnings = 3797.0
# 2019-10-26 17:00:00: P = -100.0, E = 2700.0, earnings = 3736.9999999999995
# 2019-10-26 18:00:00: P = 100.0, E = 2800.0, earnings = -3577.0000000000005
# 2019-10-26 19:00:00: P = 100.0, E = 2900.0, earnings = -3504.9999999999995
# 2019-10-26 20:00:00: P = 100.0, E = 3000.0, earnings = -3396.0
# 2019-10-26 21:00:00: P = 100.0, E = 3100.0, earnings = -3503.0
# 2019-10-26 22:00:00: P = 100.0, E = 3200.0, earnings = -3221.0
# 2019-10-26 23:00:00: P = 100.0, E = 3300.0, earnings = -3168.0
# 2019-10-27 00:00:00: P = 100.0, E = 3400.0, earnings = -3146.0
# 2019-10-27 01:00:00: P = 100.0, E = 3500.0, earnings = -3149.0
# 2019-10-27 02:00:00: P = 100.0, E = 3600.0, earnings = -3112.0
# 2019-10-27 03:00:00: P = 100.0, E = 3700.0, earnings = -3166.0
# 2019-10-27 04:00:00: P = 100.0, E = 3800.0, earnings = -3294.0
# 2019-10-27 05:00:00: P = 100.0, E = 3900.0, earnings = -3383.0
# 2019-10-27 06:00:00: P = 100.0, E = 4000.0, earnings = -3467.0
# 2019-10-27 07:00:00: P = 100.0, E = 4100.0, earnings = -3524.0
# 2019-10-27 08:00:00: P = 100.0, E = 4200.0, earnings = -3610.0
# 2019-10-27 09:00:00: P = 100.0, E = 4300.0, earnings = -3670.0000000000005
# 2019-10-27 10:00:00: P = 100.0, E = 4400.0, earnings = -3665.9999999999995
# 2019-10-27 11:00:00: P = 100.0, E = 4500.0, earnings = -3620.0000000000005
# 2019-10-27 12:00:00: P = 100.0, E = 4600.0, earnings = -3604.0
# 2019-10-27 13:00:00: P = 100.0, E = 4700.0, earnings = -3636.9999999999995
# 2019-10-27 14:00:00: P = 100.0, E = 4800.0, earnings = -3714.0
# 2019-10-27 15:00:00: P = -100.0, E = 4700.0, earnings = 3849.0
# 2019-10-27 16:00:00: P = -100.0, E = 4600.0, earnings = 4052.0000000000005
# 2019-10-27 17:00:00: P = -100.0, E = 4500.0, earnings = 4106.0
# 2019-10-27 18:00:00: P = -100.0, E = 4400.0, earnings = 4033.0
# 2019-10-27 19:00:00: P = -100.0, E = 4300.0, earnings = 3852.0000000000005
# 2019-10-27 20:00:00: P = -100.0, E = 4200.0, earnings = 3758.0
# 2019-10-27 21:00:00: P = 100.0, E = 4300.0, earnings = -3654.9999999999995
# 2019-10-27 22:00:00: P = 0.0, E = 4300.0, earnings = -0.0
# 2019-10-27 23:00:00: P = 100.0, E = 4400.0, earnings = -3547.9999999999995
# 2019-10-28 00:00:00: P = 100.0, E = 4500.0, earnings = -3536.0
# 2019-10-28 01:00:00: P = 100.0, E = 4600.0, earnings = -3550.0
# 2019-10-28 02:00:00: P = 100.0, E = 4700.0, earnings = -3574.0
# 2019-10-28 03:00:00: P = 100.0, E = 4800.0, earnings = -3696.0
# 2019-10-28 04:00:00: P = -100.0, E = 4700.0, earnings = 3845.0000000000005
# 2019-10-28 05:00:00: P = -100.0, E = 4600.0, earnings = 4000.0
# 2019-10-28 06:00:00: P = -100.0, E = 4500.0, earnings = 4099.0
# 2019-10-28 07:00:00: P = -100.0, E = 4400.0, earnings = 4237.0
# 2019-10-28 08:00:00: P = -100.0, E = 4300.0, earnings = 4214.0
# 2019-10-28 09:00:00: P = -100.0, E = 4200.0, earnings = 4168.0
# 2019-10-28 10:00:00: P = -100.0, E = 4100.0, earnings = 4097.0
# 2019-10-28 11:00:00: P = -100.0, E = 4000.0, earnings = 4058.0
# 2019-10-28 12:00:00: P = -100.0, E = 3900.0, earnings = 4092.0
# 2019-10-28 13:00:00: P = -100.0, E = 3800.0, earnings = 4089.0
# 2019-10-28 14:00:00: P = -100.0, E = 3700.0, earnings = 4089.0
# 2019-10-28 15:00:00: P = -100.0, E = 3600.0, earnings = 4107.0
# 2019-10-28 16:00:00: P = -100.0, E = 3500.0, earnings = 4068.0
# 2019-10-28 17:00:00: P = -100.0, E = 3400.0, earnings = 4004.0
# 2019-10-28 18:00:00: P = -100.0, E = 3300.0, earnings = 3975.0
# 2019-10-28 19:00:00: P = -100.0, E = 3200.0, earnings = 3976.0
# 2019-10-28 20:00:00: P = -100.0, E = 3100.0, earnings = 4020.0000000000005
# 2019-10-28 21:00:00: P = -100.0, E = 3000.0, earnings = 3933.0
# 2019-10-28 22:00:00: P = -100.0, E = 2900.0, earnings = 3861.9999999999995
# 2019-10-28 23:00:00: P = 100.0, E = 3000.0, earnings = -3702.0000000000005
# 2019-10-29 00:00:00: P = 100.0, E = 3100.0, earnings = -3660.0
# 2019-10-29 01:00:00: P = 100.0, E = 3200.0, earnings = -3583.0
# 2019-10-29 02:00:00: P = 100.0, E = 3300.0, earnings = -3522.0
# 2019-10-29 03:00:00: P = 100.0, E = 3400.0, earnings = -3606.0
# 2019-10-29 04:00:00: P = -100.0, E = 3300.0, earnings = 3815.0
# 2019-10-29 05:00:00: P = -100.0, E = 3200.0, earnings = 3975.0
# 2019-10-29 06:00:00: P = -100.0, E = 3100.0, earnings = 4040.9999999999995
# 2019-10-29 07:00:00: P = -100.0, E = 3000.0, earnings = 4059.0000000000005
# 2019-10-29 08:00:00: P = -100.0, E = 2900.0, earnings = 4086.0
# 2019-10-29 09:00:00: P = -100.0, E = 2800.0, earnings = 4132.0
# 2019-10-29 10:00:00: P = -100.0, E = 2700.0, earnings = 4103.0
# 2019-10-29 11:00:00: P = -100.0, E = 2600.0, earnings = 4103.0
# 2019-10-29 12:00:00: P = -100.0, E = 2500.0, earnings = 4103.0
# 2019-10-29 13:00:00: P = -100.0, E = 2400.0, earnings = 4090.9999999999995
# 2019-10-29 14:00:00: P = -100.0, E = 2300.0, earnings = 4098.0
# 2019-10-29 15:00:00: P = -100.0, E = 2200.0, earnings = 4137.0
# 2019-10-29 16:00:00: P = -100.0, E = 2100.0, earnings = 4144.0
# 2019-10-29 17:00:00: P = -100.0, E = 2000.0, earnings = 4149.0
# 2019-10-29 18:00:00: P = -100.0, E = 1900.0, earnings = 4101.0
# 2019-10-29 19:00:00: P = -100.0, E = 1800.0, earnings = 4057.0
# 2019-10-29 20:00:00: P = -100.0, E = 1700.0, earnings = 4052.0000000000005
# 2019-10-29 21:00:00: P = -100.0, E = 1600.0, earnings = 3993.0
# 2019-10-29 22:00:00: P = 100.0, E = 1700.0, earnings = -3657.0
# 2019-10-29 23:00:00: P = 0.0, E = 1700.0, earnings = -0.0
# 2019-10-30 00:00:00: P = 100.0, E = 1800.0, earnings = -3760.0
# 2019-10-30 01:00:00: P = 100.0, E = 1900.0, earnings = -3734.0000000000005
# 2019-10-30 02:00:00: P = 100.0, E = 2000.0, earnings = -3697.9999999999995
# 2019-10-30 03:00:00: P = 100.0, E = 2100.0, earnings = -3790.9999999999995
# 2019-10-30 04:00:00: P = -100.0, E = 2000.0, earnings = 3942.0
# 2019-10-30 05:00:00: P = -100.0, E = 1900.0, earnings = 4100.0
# 2019-10-30 06:00:00: P = -100.0, E = 1800.0, earnings = 4221.0
# 2019-10-30 07:00:00: P = -100.0, E = 1700.0, earnings = 4316.0
# 2019-10-30 08:00:00: P = -100.0, E = 1600.0, earnings = 4254.0
# 2019-10-30 09:00:00: P = -100.0, E = 1500.0, earnings = 4196.0
# 2019-10-30 10:00:00: P = -100.0, E = 1400.0, earnings = 4112.0
# 2019-10-30 11:00:00: P = -100.0, E = 1300.0, earnings = 4050.0
# 2019-10-30 12:00:00: P = -100.0, E = 1200.0, earnings = 4049.0
# 2019-10-30 13:00:00: P = -100.0, E = 1100.0, earnings = 4029.9999999999995
# 2019-10-30 14:00:00: P = -100.0, E = 1000.0, earnings = 3981.0
# 2019-10-30 15:00:00: P = -100.0, E = 900.0, earnings = 3968.0
# 2019-10-30 16:00:00: P = -100.0, E = 800.0, earnings = 3940.9999999999995
# 2019-10-30 17:00:00: P = -100.0, E = 700.0, earnings = 3911.0
# 2019-10-30 18:00:00: P = -100.0, E = 600.0, earnings = 3894.0
# 2019-10-30 19:00:00: P = 100.0, E = 700.0, earnings = -3879.0
# 2019-10-30 20:00:00: P = 100.0, E = 800.0, earnings = -3885.0
# 2019-10-30 21:00:00: P = 100.0, E = 900.0, earnings = -3832.0
# 2019-10-30 22:00:00: P = 100.0, E = 1000.0, earnings = -3754.0
# 2019-10-30 23:00:00: P = 100.0, E = 1100.0, earnings = -3620.0000000000005
# 2019-10-31 00:00:00: P = 100.0, E = 1200.0, earnings = -3497.9999999999995
# 2019-10-31 01:00:00: P = 100.0, E = 1300.0, earnings = -3394.0
# 2019-10-31 02:00:00: P = 100.0, E = 1400.0, earnings = -3315.9999999999995
# 2019-10-31 03:00:00: P = 100.0, E = 1500.0, earnings = -3485.0
# 2019-10-31 04:00:00: P = 100.0, E = 1600.0, earnings = -3786.0
# 2019-10-31 05:00:00: P = -100.0, E = 1500.0, earnings = 3968.0
# 2019-10-31 06:00:00: P = -100.0, E = 1400.0, earnings = 4002.0000000000005
# 2019-10-31 07:00:00: P = -100.0, E = 1300.0, earnings = 4022.9999999999995
# 2019-10-31 08:00:00: P = -100.0, E = 1200.0, earnings = 4032.0
# 2019-10-31 09:00:00: P = -100.0, E = 1100.0, earnings = 4051.0
# 2019-10-31 10:00:00: P = -100.0, E = 1000.0, earnings = 4010.0
# 2019-10-31 11:00:00: P = -100.0, E = 900.0, earnings = 3938.0000000000005
# 2019-10-31 12:00:00: P = -100.0, E = 800.0, earnings = 4015.0
# 2019-10-31 13:00:00: P = -100.0, E = 700.0, earnings = 4047.9999999999995
# 2019-10-31 14:00:00: P = -100.0, E = 600.0, earnings = 4036.9999999999995
# 2019-10-31 15:00:00: P = -100.0, E = 500.0, earnings = 4004.9999999999995
# 2019-10-31 16:00:00: P = -100.0, E = 400.0, earnings = 4021.0
# 2019-10-31 17:00:00: P = -100.0, E = 300.0, earnings = 4010.0
# 2019-10-31 18:00:00: P = -100.0, E = 200.0, earnings = 4011.9999999999995
# 2019-10-31 19:00:00: P = -100.0, E = 100.0, earnings = 4007.0
# 2019-10-31 20:00:00: P = -100.0, E = 0.0, earnings = 4007.0
# 2019-10-31 21:00:00: P = -100.0, E = -100.0, earnings = 3968.0
# 2019-10-31 22:00:00: P = 100.0, E = 0.0, earnings = -3078.0
# 2019-10-31 23:00:00: P = 100.0, E = 100.0, earnings = -3651.0
# 2019-11-01 00:00:00: P = 100.0, E = 200.0, earnings = -3488.0000000000005
# 2019-11-01 01:00:00: P = 100.0, E = 300.0, earnings = -3451.0
# 2019-11-01 02:00:00: P = 100.0, E = 400.0, earnings = -3442.0
# 2019-11-01 03:00:00: P = 100.0, E = 500.0, earnings = -3557.0
# 2019-11-01 04:00:00: P = 100.0, E = 600.0, earnings = -3738.0000000000005
# 2019-11-01 05:00:00: P = 100.0, E = 700.0, earnings = -3851.0
# 2019-11-01 06:00:00: P = -100.0, E = 600.0, earnings = 3983.0
# 2019-11-01 07:00:00: P = -100.0, E = 500.0, earnings = 4017.0
# 2019-11-01 08:00:00: P = -100.0, E = 400.0, earnings = 3986.9999999999995
# 2019-11-01 09:00:00: P = -100.0, E = 300.0, earnings = 3974.0
# 2019-11-01 10:00:00: P = -100.0, E = 200.0, earnings = 3940.9999999999995
# 2019-11-01 11:00:00: P = -100.0, E = 100.0, earnings = 3890.9999999999995
# 2019-11-01 12:00:00: P = 100.0, E = 200.0, earnings = -3878.0
# 2019-11-01 13:00:00: P = 100.0, E = 300.0, earnings = -3844.0
# 2019-11-01 14:00:00: P = 100.0, E = 400.0, earnings = -3804.9999999999995
# 2019-11-01 15:00:00: P = 100.0, E = 500.0, earnings = -3861.9999999999995
# 2019-11-01 16:00:00: P = -100.0, E = 400.0, earnings = 3919.0
# 2019-11-01 17:00:00: P = -100.0, E = 300.0, earnings = 3902.0000000000005
# 2019-11-01 18:00:00: P = 100.0, E = 400.0, earnings = -3822.9999999999995
# 2019-11-01 19:00:00: P = 100.0, E = 500.0, earnings = -3731.0
# 2019-11-01 20:00:00: P = 100.0, E = 600.0, earnings = -3626.0
# 2019-11-01 21:00:00: P = 100.0, E = 700.0, earnings = -3404.0
# 2019-11-01 22:00:00: P = 100.0, E = 800.0, earnings = -3390.9999999999995
# 2019-11-01 23:00:00: P = 100.0, E = 900.0, earnings = -3150.0
# 2019-11-02 00:00:00: P = 100.0, E = 1000.0, earnings = -3007.0
# 2019-11-02 01:00:00: P = 100.0, E = 1100.0, earnings = -2801.0
# 2019-11-02 02:00:00: P = 100.0, E = 1200.0, earnings = -2700.0
# 2019-11-02 03:00:00: P = 100.0, E = 1300.0, earnings = -2806.0
# 2019-11-02 04:00:00: P = 100.0, E = 1400.0, earnings = -3010.0
# 2019-11-02 05:00:00: P = 100.0, E = 1500.0, earnings = -3443.0
# 2019-11-02 06:00:00: P = 100.0, E = 1600.0, earnings = -3570.0000000000005
# 2019-11-02 07:00:00: P = 100.0, E = 1700.0, earnings = -3659.0000000000005
# 2019-11-02 08:00:00: P = 100.0, E = 1800.0, earnings = -3795.0000000000005
# 2019-11-02 09:00:00: P = 100.0, E = 1900.0, earnings = -3843.0
# 2019-11-02 10:00:00: P = 100.0, E = 2000.0, earnings = -3817.0
# 2019-11-02 11:00:00: P = 100.0, E = 2100.0, earnings = -3747.0
# 2019-11-02 12:00:00: P = 100.0, E = 2200.0, earnings = -3711.0
# 2019-11-02 13:00:00: P = 100.0, E = 2300.0, earnings = -3704.0
# 2019-11-02 14:00:00: P = 100.0, E = 2400.0, earnings = -3729.0
# 2019-11-02 15:00:00: P = 100.0, E = 2500.0, earnings = -3842.0
# 2019-11-02 16:00:00: P = -100.0, E = 2400.0, earnings = 3893.0
# 2019-11-02 17:00:00: P = -100.0, E = 2300.0, earnings = 3944.0
# 2019-11-02 18:00:00: P = 100.0, E = 2400.0, earnings = -3731.0
# 2019-11-02 19:00:00: P = 100.0, E = 2500.0, earnings = -3688.0000000000005
# 2019-11-02 20:00:00: P = 100.0, E = 2600.0, earnings = -3636.0
# 2019-11-02 21:00:00: P = 100.0, E = 2700.0, earnings = -3519.0
# 2019-11-02 22:00:00: P = 100.0, E = 2800.0, earnings = -3410.0
# 2019-11-02 23:00:00: P = 100.0, E = 2900.0, earnings = -3452.0000000000005
# 2019-11-03 00:00:00: P = 100.0, E = 3000.0, earnings = -3290.9999999999995
# 2019-11-03 01:00:00: P = 100.0, E = 3100.0, earnings = -3043.0
# 2019-11-03 02:00:00: P = 100.0, E = 3200.0, earnings = -2928.0
# 2019-11-03 03:00:00: P = 100.0, E = 3300.0, earnings = -3044.0
# 2019-11-03 04:00:00: P = 100.0, E = 3400.0, earnings = -3165.0
# 2019-11-03 05:00:00: P = 100.0, E = 3500.0, earnings = -3347.9999999999995
# 2019-11-03 06:00:00: P = 100.0, E = 3600.0, earnings = -3443.0
# 2019-11-03 07:00:00: P = 100.0, E = 3700.0, earnings = -3588.0000000000005
# 2019-11-03 08:00:00: P = 100.0, E = 3800.0, earnings = -3688.0000000000005
# 2019-11-03 09:00:00: P = 100.0, E = 3900.0, earnings = -3759.0000000000005
# 2019-11-03 10:00:00: P = 100.0, E = 4000.0, earnings = -3814.0
# 2019-11-03 11:00:00: P = 100.0, E = 4100.0, earnings = -3869.0
# 2019-11-03 12:00:00: P = 100.0, E = 4200.0, earnings = -3809.0000000000005
# 2019-11-03 13:00:00: P = 100.0, E = 4300.0, earnings = -3822.9999999999995
# 2019-11-03 14:00:00: P = 100.0, E = 4400.0, earnings = -3854.0
# 2019-11-03 15:00:00: P = -100.0, E = 4300.0, earnings = 3976.0
# 2019-11-03 16:00:00: P = -100.0, E = 4200.0, earnings = 4042.0
# 2019-11-03 17:00:00: P = -100.0, E = 4100.0, earnings = 4068.0
# 2019-11-03 18:00:00: P = -100.0, E = 4000.0, earnings = 4039.0
# 2019-11-03 19:00:00: P = -100.0, E = 3900.0, earnings = 3924.0
# 2019-11-03 20:00:00: P = 100.0, E = 4000.0, earnings = -3743.0
# 2019-11-03 21:00:00: P = 100.0, E = 4100.0, earnings = -3586.0
# 2019-11-03 22:00:00: P = 100.0, E = 4200.0, earnings = -3660.0
# 2019-11-03 23:00:00: P = 100.0, E = 4300.0, earnings = -3476.0
# 2019-11-04 00:00:00: P = 100.0, E = 4400.0, earnings = -3456.0
# 2019-11-04 01:00:00: P = 100.0, E = 4500.0, earnings = -3460.0
# 2019-11-04 02:00:00: P = 100.0, E = 4600.0, earnings = -3446.0
# 2019-11-04 03:00:00: P = 100.0, E = 4700.0, earnings = -3547.0
# 2019-11-04 04:00:00: P = 100.0, E = 4800.0, earnings = -3636.9999999999995
# 2019-11-04 05:00:00: P = 0.0, E = 4800.0, earnings = -0.0
# 2019-11-04 06:00:00: P = -100.0, E = 4700.0, earnings = 4165.0
# 2019-11-04 07:00:00: P = -100.0, E = 4600.0, earnings = 4325.0
# 2019-11-04 08:00:00: P = -100.0, E = 4500.0, earnings = 4404.0
# 2019-11-04 09:00:00: P = -100.0, E = 4400.0, earnings = 4301.0
# 2019-11-04 10:00:00: P = -100.0, E = 4300.0, earnings = 4225.0
# 2019-11-04 11:00:00: P = -100.0, E = 4200.0, earnings = 4171.0
# 2019-11-04 12:00:00: P = -100.0, E = 4100.0, earnings = 4226.0
# 2019-11-04 13:00:00: P = -100.0, E = 4000.0, earnings = 4222.0
# 2019-11-04 14:00:00: P = -100.0, E = 3900.0, earnings = 4242.0
# 2019-11-04 15:00:00: P = -100.0, E = 3800.0, earnings = 4350.0
# 2019-11-04 16:00:00: P = -100.0, E = 3700.0, earnings = 4428.0
# 2019-11-04 17:00:00: P = -100.0, E = 3600.0, earnings = 4394.0
# 2019-11-04 18:00:00: P = -100.0, E = 3500.0, earnings = 4265.0
# 2019-11-04 19:00:00: P = 100.0, E = 3600.0, earnings = -4169.0
# 2019-11-04 20:00:00: P = 100.0, E = 3700.0, earnings = -4000.0
# 2019-11-04 21:00:00: P = 100.0, E = 3800.0, earnings = -3897.9999999999995
# 2019-11-04 22:00:00: P = 100.0, E = 3900.0, earnings = -3957.0
# 2019-11-04 23:00:00: P = 100.0, E = 4000.0, earnings = -3708.0
# 2019-11-05 00:00:00: P = 100.0, E = 4100.0, earnings = -3657.0
# 2019-11-05 01:00:00: P = 100.0, E = 4200.0, earnings = -3636.9999999999995
# 2019-11-05 02:00:00: P = 100.0, E = 4300.0, earnings = -3647.9999999999995
# 2019-11-05 03:00:00: P = 100.0, E = 4400.0, earnings = -3785.0
# 2019-11-05 04:00:00: P = 100.0, E = 4500.0, earnings = -4061.9999999999995
# 2019-11-05 05:00:00: P = 0.0, E = 4500.0, earnings = -0.0
# 2019-11-05 06:00:00: P = -100.0, E = 4400.0, earnings = 4510.0
# 2019-11-05 07:00:00: P = -100.0, E = 4300.0, earnings = 4630.0
# 2019-11-05 08:00:00: P = -100.0, E = 4200.0, earnings = 4539.0
# 2019-11-05 09:00:00: P = -100.0, E = 4100.0, earnings = 4530.0
# 2019-11-05 10:00:00: P = -100.0, E = 4000.0, earnings = 4496.0
# 2019-11-05 11:00:00: P = -100.0, E = 3900.0, earnings = 4484.0
# 2019-11-05 12:00:00: P = -100.0, E = 3800.0, earnings = 4476.0
# 2019-11-05 13:00:00: P = -100.0, E = 3700.0, earnings = 4467.0
# 2019-11-05 14:00:00: P = -100.0, E = 3600.0, earnings = 4314.0
# 2019-11-05 15:00:00: P = -100.0, E = 3500.0, earnings = 4343.0
# 2019-11-05 16:00:00: P = -100.0, E = 3400.0, earnings = 4627.0
# 2019-11-05 17:00:00: P = -100.0, E = 3300.0, earnings = 4753.0
# 2019-11-05 18:00:00: P = -100.0, E = 3200.0, earnings = 4656.0
# 2019-11-05 19:00:00: P = -100.0, E = 3100.0, earnings = 4492.0
# 2019-11-05 20:00:00: P = -100.0, E = 3000.0, earnings = 4238.0
# 2019-11-05 21:00:00: P = 100.0, E = 3100.0, earnings = -4121.0
# 2019-11-05 22:00:00: P = 100.0, E = 3200.0, earnings = -4139.0
# 2019-11-05 23:00:00: P = 100.0, E = 3300.0, earnings = -4040.0
# 2019-11-06 00:00:00: P = 100.0, E = 3400.0, earnings = -3999.0
# 2019-11-06 01:00:00: P = 100.0, E = 3500.0, earnings = -3997.0
# 2019-11-06 02:00:00: P = 100.0, E = 3600.0, earnings = -4020.0000000000005
# 2019-11-06 03:00:00: P = 100.0, E = 3700.0, earnings = -4103.0
# 2019-11-06 04:00:00: P = 100.0, E = 3800.0, earnings = -4139.0
# 2019-11-06 05:00:00: P = -100.0, E = 3700.0, earnings = 4563.0
# 2019-11-06 06:00:00: P = -100.0, E = 3600.0, earnings = 5577.0
# 2019-11-06 07:00:00: P = -100.0, E = 3500.0, earnings = 5968.0
# 2019-11-06 08:00:00: P = -100.0, E = 3400.0, earnings = 5692.0
# 2019-11-06 09:00:00: P = -100.0, E = 3300.0, earnings = 5680.0
# 2019-11-06 10:00:00: P = -100.0, E = 3200.0, earnings = 5644.0
# 2019-11-06 11:00:00: P = -100.0, E = 3100.0, earnings = 5442.0
# 2019-11-06 12:00:00: P = -100.0, E = 3000.0, earnings = 5580.0
# 2019-11-06 13:00:00: P = -100.0, E = 2900.0, earnings = 5728.0
# 2019-11-06 14:00:00: P = -100.0, E = 2800.0, earnings = 5739.0
# 2019-11-06 15:00:00: P = -100.0, E = 2700.0, earnings = 6071.0
# 2019-11-06 16:00:00: P = -100.0, E = 2600.0, earnings = 7625.0
# 2019-11-06 17:00:00: P = -100.0, E = 2500.0, earnings = 8075.0
# 2019-11-06 18:00:00: P = -100.0, E = 2400.0, earnings = 6292.0
# 2019-11-06 19:00:00: P = -100.0, E = 2300.0, earnings = 5273.0
# 2019-11-06 20:00:00: P = -100.0, E = 2200.0, earnings = 4622.0
# 2019-11-06 21:00:00: P = -100.0, E = 2100.0, earnings = 4353.0
# 2019-11-06 22:00:00: P = 100.0, E = 2200.0, earnings = -4127.0
# 2019-11-06 23:00:00: P = 100.0, E = 2300.0, earnings = -4197.0
# 2019-11-07 00:00:00: P = 100.0, E = 2400.0, earnings = -4114.0
# 2019-11-07 01:00:00: P = 100.0, E = 2500.0, earnings = -4068.0
# 2019-11-07 02:00:00: P = 100.0, E = 2600.0, earnings = -4097.0
# 2019-11-07 03:00:00: P = -100.0, E = 2500.0, earnings = 4211.0
# 2019-11-07 04:00:00: P = -100.0, E = 2400.0, earnings = 4306.0
# 2019-11-07 05:00:00: P = -100.0, E = 2300.0, earnings = 4568.0
# 2019-11-07 06:00:00: P = -100.0, E = 2200.0, earnings = 5390.0
# 2019-11-07 07:00:00: P = -100.0, E = 2100.0, earnings = 5865.0
# 2019-11-07 08:00:00: P = -100.0, E = 2000.0, earnings = 5287.0
# 2019-11-07 09:00:00: P = -100.0, E = 1900.0, earnings = 4949.0
# 2019-11-07 10:00:00: P = -100.0, E = 1800.0, earnings = 4789.0
# 2019-11-07 11:00:00: P = -100.0, E = 1700.0, earnings = 4715.0
# 2019-11-07 12:00:00: P = -100.0, E = 1600.0, earnings = 4683.0
# 2019-11-07 13:00:00: P = -100.0, E = 1500.0, earnings = 4673.0
# 2019-11-07 14:00:00: P = -100.0, E = 1400.0, earnings = 4742.0
# 2019-11-07 15:00:00: P = -100.0, E = 1300.0, earnings = 4988.0
# 2019-11-07 16:00:00: P = -100.0, E = 1200.0, earnings = 5243.0
# 2019-11-07 17:00:00: P = -100.0, E = 1100.0, earnings = 4819.0
# 2019-11-07 18:00:00: P = -100.0, E = 1000.0, earnings = 4672.0
# 2019-11-07 19:00:00: P = -100.0, E = 900.0, earnings = 4498.0
# 2019-11-07 20:00:00: P = -100.0, E = 800.0, earnings = 4339.0
# 2019-11-07 21:00:00: P = -100.0, E = 700.0, earnings = 4213.0
# 2019-11-07 22:00:00: P = 100.0, E = 800.0, earnings = -4064.0
# 2019-11-07 23:00:00: P = 100.0, E = 900.0, earnings = -3990.9999999999995
# 2019-11-08 00:00:00: P = 100.0, E = 1000.0, earnings = -3940.0
# 2019-11-08 01:00:00: P = 100.0, E = 1100.0, earnings = -3920.0000000000005
# 2019-11-08 02:00:00: P = 100.0, E = 1200.0, earnings = -3922.9999999999995
# 2019-11-08 03:00:00: P = 100.0, E = 1300.0, earnings = -3989.0
# 2019-11-08 04:00:00: P = 100.0, E = 1400.0, earnings = -4196.0
# 2019-11-08 05:00:00: P = -100.0, E = 1300.0, earnings = 4505.0
# 2019-11-08 06:00:00: P = -100.0, E = 1200.0, earnings = 5178.0
# 2019-11-08 07:00:00: P = -100.0, E = 1100.0, earnings = 5432.0
# 2019-11-08 08:00:00: P = -100.0, E = 1000.0, earnings = 5562.0
# 2019-11-08 09:00:00: P = -100.0, E = 900.0, earnings = 5494.0
# 2019-11-08 10:00:00: P = -100.0, E = 800.0, earnings = 5395.0
# 2019-11-08 11:00:00: P = -100.0, E = 700.0, earnings = 5244.0
# 2019-11-08 12:00:00: P = -100.0, E = 600.0, earnings = 5226.0
# 2019-11-08 13:00:00: P = -100.0, E = 500.0, earnings = 5241.0
# 2019-11-08 14:00:00: P = -100.0, E = 400.0, earnings = 4842.0
# 2019-11-08 15:00:00: P = -100.0, E = 300.0, earnings = 4801.0
# 2019-11-08 16:00:00: P = -100.0, E = 200.0, earnings = 4898.0
# 2019-11-08 17:00:00: P = -100.0, E = 100.0, earnings = 4704.0
# 2019-11-08 18:00:00: P = -100.0, E = 0.0, earnings = 4602.0
# 2019-11-08 19:00:00: P = -100.0, E = -100.0, earnings = 4493.0
# 2019-11-08 20:00:00: P = -100.0, E = -200.0, earnings = 4383.0
# 2019-11-08 21:00:00: P = -100.0, E = -300.0, earnings = 4298.0
# 2019-11-08 22:00:00: P = 100.0, E = -200.0, earnings = -3667.0
# 2019-11-08 23:00:00: P = 100.0, E = -100.0, earnings = -4191.0
# 2019-11-09 00:00:00: P = 100.0, E = 0.0, earnings = -4050.0
# 2019-11-09 01:00:00: P = 100.0, E = 100.0, earnings = -3978.0
# 2019-11-09 02:00:00: P = 100.0, E = 200.0, earnings = -3924.0
# 2019-11-09 03:00:00: P = 100.0, E = 300.0, earnings = -3929.9999999999995
# 2019-11-09 04:00:00: P = 100.0, E = 400.0, earnings = -3949.0
# 2019-11-09 05:00:00: P = 100.0, E = 500.0, earnings = -4054.0
# 2019-11-09 06:00:00: P = 100.0, E = 600.0, earnings = -4156.0
# 2019-11-09 07:00:00: P = -100.0, E = 500.0, earnings = 4202.0
# 2019-11-09 08:00:00: P = -100.0, E = 400.0, earnings = 4457.0
# 2019-11-09 09:00:00: P = -100.0, E = 300.0, earnings = 4415.0
# 2019-11-09 10:00:00: P = -100.0, E = 200.0, earnings = 4310.0
# 2019-11-09 11:00:00: P = -100.0, E = 100.0, earnings = 4219.0
# 2019-11-09 12:00:00: P = 100.0, E = 200.0, earnings = -4133.0
# 2019-11-09 13:00:00: P = 100.0, E = 300.0, earnings = -4124.0
# 2019-11-09 14:00:00: P = -100.0, E = 200.0, earnings = 4169.0
# 2019-11-09 15:00:00: P = -100.0, E = 100.0, earnings = 4381.0
# 2019-11-09 16:00:00: P = -100.0, E = 0.0, earnings = 4596.0
# 2019-11-09 17:00:00: P = -100.0, E = -100.0, earnings = 4524.0
# 2019-11-09 18:00:00: P = -100.0, E = -200.0, earnings = 4409.0
# 2019-11-09 19:00:00: P = -100.0, E = -300.0, earnings = 4180.0
# 2019-11-09 20:00:00: P = 100.0, E = -200.0, earnings = -4071.0
# 2019-11-09 21:00:00: P = 100.0, E = -100.0, earnings = -3965.9999999999995
# 2019-11-09 22:00:00: P = 100.0, E = 0.0, earnings = -4086.0
# 2019-11-09 23:00:00: P = 100.0, E = 100.0, earnings = -3849.0
# 2019-11-10 00:00:00: P = 100.0, E = 200.0, earnings = -3747.0
# 2019-11-10 01:00:00: P = 100.0, E = 300.0, earnings = -3693.0
# 2019-11-10 02:00:00: P = 100.0, E = 400.0, earnings = -3675.0
# 2019-11-10 03:00:00: P = 100.0, E = 500.0, earnings = -3727.0000000000005
# 2019-11-10 04:00:00: P = 100.0, E = 600.0, earnings = -3756.0
# 2019-11-10 05:00:00: P = 100.0, E = 700.0, earnings = -3740.0
# 2019-11-10 06:00:00: P = 100.0, E = 800.0, earnings = -3894.0
# 2019-11-10 07:00:00: P = 100.0, E = 900.0, earnings = -3997.0
# 2019-11-10 08:00:00: P = 100.0, E = 1000.0, earnings = -4040.9999999999995
# 2019-11-10 09:00:00: P = 100.0, E = 1100.0, earnings = -4092.0
# 2019-11-10 10:00:00: P = 100.0, E = 1200.0, earnings = -4100.0
# 2019-11-10 11:00:00: P = 100.0, E = 1300.0, earnings = -4133.0
# 2019-11-10 12:00:00: P = 100.0, E = 1400.0, earnings = -4088.0000000000005
# 2019-11-10 13:00:00: P = 100.0, E = 1500.0, earnings = -4107.0
# 2019-11-10 14:00:00: P = -100.0, E = 1400.0, earnings = 4237.0
# 2019-11-10 15:00:00: P = -100.0, E = 1300.0, earnings = 4530.0
# 2019-11-10 16:00:00: P = -100.0, E = 1200.0, earnings = 5050.0
# 2019-11-10 17:00:00: P = -100.0, E = 1100.0, earnings = 5139.0
# 2019-11-10 18:00:00: P = -100.0, E = 1000.0, earnings = 4942.0
# 2019-11-10 19:00:00: P = -100.0, E = 900.0, earnings = 4686.0
# 2019-11-10 20:00:00: P = -100.0, E = 800.0, earnings = 4484.0
# 2019-11-10 21:00:00: P = -100.0, E = 700.0, earnings = 4319.0
# 2019-11-10 22:00:00: P = 100.0, E = 800.0, earnings = -3938.0000000000005
# 2019-11-10 23:00:00: P = 100.0, E = 900.0, earnings = -4019.0
# 2019-11-11 00:00:00: P = 100.0, E = 1000.0, earnings = -3984.0000000000005
# 2019-11-11 01:00:00: P = 100.0, E = 1100.0, earnings = -3972.0
# 2019-11-11 02:00:00: P = 100.0, E = 1200.0, earnings = -3978.0
# 2019-11-11 03:00:00: P = 100.0, E = 1300.0, earnings = -4010.0
# 2019-11-11 04:00:00: P = -100.0, E = 1200.0, earnings = 4134.0
# 2019-11-11 05:00:00: P = -100.0, E = 1100.0, earnings = 4355.0
# 2019-11-11 06:00:00: P = -100.0, E = 1000.0, earnings = 4769.0
# 2019-11-11 07:00:00: P = -100.0, E = 900.0, earnings = 5100.0
# 2019-11-11 08:00:00: P = -100.0, E = 800.0, earnings = 4864.0
# 2019-11-11 09:00:00: P = -100.0, E = 700.0, earnings = 4688.0
# 2019-11-11 10:00:00: P = -100.0, E = 600.0, earnings = 4642.0
# 2019-11-11 11:00:00: P = -100.0, E = 500.0, earnings = 4527.0
# 2019-11-11 12:00:00: P = -100.0, E = 400.0, earnings = 4560.0
# 2019-11-11 13:00:00: P = -100.0, E = 300.0, earnings = 4415.0
# 2019-11-11 14:00:00: P = -100.0, E = 200.0, earnings = 4462.0
# 2019-11-11 15:00:00: P = -100.0, E = 100.0, earnings = 4478.0
# 2019-11-11 16:00:00: P = -100.0, E = 0.0, earnings = 4717.0
# 2019-11-11 17:00:00: P = -100.0, E = -100.0, earnings = 4539.0
# 2019-11-11 18:00:00: P = -100.0, E = -200.0, earnings = 4269.0
# 2019-11-11 19:00:00: P = -100.0, E = -300.0, earnings = 4196.0
# 2019-11-11 20:00:00: P = 100.0, E = -200.0, earnings = -4099.0
# 2019-11-11 21:00:00: P = 100.0, E = -100.0, earnings = -4039.0
# 2019-11-11 22:00:00: P = 100.0, E = 0.0, earnings = -3764.0
# 2019-11-11 23:00:00: P = 100.0, E = 100.0, earnings = -3695.0000000000005
# 2019-11-12 00:00:00: P = 100.0, E = 200.0, earnings = -3660.0
# 2019-11-12 01:00:00: P = 100.0, E = 300.0, earnings = -3631.0
# 2019-11-12 02:00:00: P = 100.0, E = 400.0, earnings = -3635.0
# 2019-11-12 03:00:00: P = 100.0, E = 500.0, earnings = -3802.0000000000005
# 2019-11-12 04:00:00: P = 100.0, E = 600.0, earnings = -4050.0
# 2019-11-12 05:00:00: P = -100.0, E = 500.0, earnings = 4125.0
# 2019-11-12 06:00:00: P = -100.0, E = 400.0, earnings = 4387.0
# 2019-11-12 07:00:00: P = -100.0, E = 300.0, earnings = 4399.0
# 2019-11-12 08:00:00: P = -100.0, E = 200.0, earnings = 4300.0
# 2019-11-12 09:00:00: P = -100.0, E = 100.0, earnings = 4241.0
# 2019-11-12 10:00:00: P = -100.0, E = 0.0, earnings = 4203.0
# 2019-11-12 11:00:00: P = -100.0, E = -100.0, earnings = 4194.0
# 2019-11-12 12:00:00: P = -100.0, E = -200.0, earnings = 4260.0
# 2019-11-12 13:00:00: P = -100.0, E = -300.0, earnings = 4339.0
# 2019-11-12 14:00:00: P = -100.0, E = -400.0, earnings = 4398.0
# 2019-11-12 15:00:00: P = -100.0, E = -500.0, earnings = 4417.0
# 2019-11-12 16:00:00: P = -100.0, E = -600.0, earnings = 4333.0
# 2019-11-12 17:00:00: P = -100.0, E = -700.0, earnings = 4308.0
# 2019-11-12 18:00:00: P = -100.0, E = -800.0, earnings = 4202.0
# 2019-11-12 19:00:00: P = -100.0, E = -900.0, earnings = 4155.0
# 2019-11-12 20:00:00: P = 100.0, E = -800.0, earnings = -4095.0000000000005
# 2019-11-12 21:00:00: P = 100.0, E = -700.0, earnings = -4002.0000000000005
# 2019-11-12 22:00:00: P = 100.0, E = -600.0, earnings = -4072.0
# 2019-11-12 23:00:00: P = 100.0, E = -500.0, earnings = -3484.0000000000005
# 2019-11-13 00:00:00: P = 100.0, E = -400.0, earnings = -3483.0
# 2019-11-13 01:00:00: P = 100.0, E = -300.0, earnings = -3501.0
# 2019-11-13 02:00:00: P = 100.0, E = -200.0, earnings = -3522.0
# 2019-11-13 03:00:00: P = 100.0, E = -100.0, earnings = -3803.0
# 2019-11-13 04:00:00: P = 100.0, E = 0.0, earnings = -4075.0
# 2019-11-13 05:00:00: P = -100.0, E = -100.0, earnings = 4205.0
# 2019-11-13 06:00:00: P = -100.0, E = -200.0, earnings = 4286.0
# 2019-11-13 07:00:00: P = -100.0, E = -300.0, earnings = 4300.0
# 2019-11-13 08:00:00: P = -100.0, E = -400.0, earnings = 4293.0
# 2019-11-13 09:00:00: P = -100.0, E = -500.0, earnings = 4287.0
# 2019-11-13 10:00:00: P = -100.0, E = -600.0, earnings = 4300.0
# 2019-11-13 11:00:00: P = -100.0, E = -700.0, earnings = 4296.0
# 2019-11-13 12:00:00: P = -100.0, E = -800.0, earnings = 4294.0
# 2019-11-13 13:00:00: P = -100.0, E = -900.0, earnings = 4302.0
# 2019-11-13 14:00:00: P = -100.0, E = -1000.0, earnings = 4329.0
# 2019-11-13 15:00:00: P = -100.0, E = -1100.0, earnings = 4351.0
# 2019-11-13 16:00:00: P = -100.0, E = -1200.0, earnings = 4360.0
# 2019-11-13 17:00:00: P = -100.0, E = -1300.0, earnings = 4478.0
# 2019-11-13 18:00:00: P = -100.0, E = -1400.0, earnings = 4347.0
# 2019-11-13 19:00:00: P = -100.0, E = -1500.0, earnings = 4339.0
# 2019-11-13 20:00:00: P = -100.0, E = -1600.0, earnings = 4291.0
# 2019-11-13 21:00:00: P = 100.0, E = -1500.0, earnings = -4147.0
# 2019-11-13 22:00:00: P = 100.0, E = -1400.0, earnings = -4067.0
# 2019-11-13 23:00:00: P = 100.0, E = -1300.0, earnings = -4021.0
# 2019-11-14 00:00:00: P = 100.0, E = -1200.0, earnings = -3990.0
# 2019-11-14 01:00:00: P = 100.0, E = -1100.0, earnings = -3956.0
# 2019-11-14 02:00:00: P = 100.0, E = -1000.0, earnings = -3967.0
# 2019-11-14 03:00:00: P = 100.0, E = -900.0, earnings = -4019.0
# 2019-11-14 04:00:00: P = 100.0, E = -800.0, earnings = -4103.0
# 2019-11-14 05:00:00: P = -100.0, E = -900.0, earnings = 4345.0
# 2019-11-14 06:00:00: P = -100.0, E = -1000.0, earnings = 4426.0
# 2019-11-14 07:00:00: P = -100.0, E = -1100.0, earnings = 4498.0
# 2019-11-14 08:00:00: P = -100.0, E = -1200.0, earnings = 4441.0
# 2019-11-14 09:00:00: P = -100.0, E = -1300.0, earnings = 4399.0
# 2019-11-14 10:00:00: P = -100.0, E = -1400.0, earnings = 4388.0
# 2019-11-14 11:00:00: P = -100.0, E = -1500.0, earnings = 4465.0
# 2019-11-14 12:00:00: P = -100.0, E = -1600.0, earnings = 4481.0
# 2019-11-14 13:00:00: P = -100.0, E = -1700.0, earnings = 4416.0
# 2019-11-14 14:00:00: P = -100.0, E = -1800.0, earnings = 4415.0
# 2019-11-14 15:00:00: P = -100.0, E = -1900.0, earnings = 4487.0
# 2019-11-14 16:00:00: P = -100.0, E = -2000.0, earnings = 4428.0
# 2019-11-14 17:00:00: P = -100.0, E = -2100.0, earnings = 4456.0
# 2019-11-14 18:00:00: P = -100.0, E = -2200.0, earnings = 4375.0
# 2019-11-14 19:00:00: P = -100.0, E = -2300.0, earnings = 4273.0
# 2019-11-14 20:00:00: P = -100.0, E = -2400.0, earnings = 4205.0
# 2019-11-14 21:00:00: P = 100.0, E = -2300.0, earnings = -4106.0
# 2019-11-14 22:00:00: P = 100.0, E = -2200.0, earnings = -3846.0
# 2019-11-14 23:00:00: P = 100.0, E = -2100.0, earnings = -3875.0
# 2019-11-15 00:00:00: P = 100.0, E = -2000.0, earnings = -3703.0
# 2019-11-15 01:00:00: P = 100.0, E = -1900.0, earnings = -3664.0
# 2019-11-15 02:00:00: P = 100.0, E = -1800.0, earnings = -3682.0
# 2019-11-15 03:00:00: P = 100.0, E = -1700.0, earnings = -3794.0
# 2019-11-15 04:00:00: P = 100.0, E = -1600.0, earnings = -4002.0000000000005
# 2019-11-15 05:00:00: P = 100.0, E = -1500.0, earnings = -4121.0
# 2019-11-15 06:00:00: P = -100.0, E = -1600.0, earnings = 4244.0
# 2019-11-15 07:00:00: P = -100.0, E = -1700.0, earnings = 4242.0
# 2019-11-15 08:00:00: P = -100.0, E = -1800.0, earnings = 4196.0
# 2019-11-15 09:00:00: P = -100.0, E = -1900.0, earnings = 4172.0
# 2019-11-15 10:00:00: P = -100.0, E = -2000.0, earnings = 4164.0
# 2019-11-15 11:00:00: P = 100.0, E = -1900.0, earnings = -4134.0
# 2019-11-15 12:00:00: P = 100.0, E = -1800.0, earnings = -4145.0
# 2019-11-15 13:00:00: P = -100.0, E = -1900.0, earnings = 4200.0
# 2019-11-15 14:00:00: P = -100.0, E = -2000.0, earnings = 4275.0
# 2019-11-15 15:00:00: P = -100.0, E = -2100.0, earnings = 4360.0
# 2019-11-15 16:00:00: P = -100.0, E = -2200.0, earnings = 4427.0
# 2019-11-15 17:00:00: P = -100.0, E = -2300.0, earnings = 4341.0
# 2019-11-15 18:00:00: P = -100.0, E = -2400.0, earnings = 4240.0
# 2019-11-15 19:00:00: P = 100.0, E = -2300.0, earnings = -4155.0
# 2019-11-15 20:00:00: P = 100.0, E = -2200.0, earnings = -4135.0
# 2019-11-15 21:00:00: P = 100.0, E = -2100.0, earnings = -4004.0
# 2019-11-15 22:00:00: P = 100.0, E = -2000.0, earnings = -3644.0
# 2019-11-15 23:00:00: P = 100.0, E = -1900.0, earnings = -3697.9999999999995
# 2019-11-16 00:00:00: P = 100.0, E = -1800.0, earnings = -3707.0
# 2019-11-16 01:00:00: P = 100.0, E = -1700.0, earnings = -3653.0
# 2019-11-16 02:00:00: P = 100.0, E = -1600.0, earnings = -3719.0
# 2019-11-16 03:00:00: P = 100.0, E = -1500.0, earnings = -3732.0
# 2019-11-16 04:00:00: P = 100.0, E = -1400.0, earnings = -3749.0
# 2019-11-16 05:00:00: P = 100.0, E = -1300.0, earnings = -3842.0
# 2019-11-16 06:00:00: P = 100.0, E = -1200.0, earnings = -3943.0
# 2019-11-16 07:00:00: P = 100.0, E = -1100.0, earnings = -4111.0
# 2019-11-16 08:00:00: P = -100.0, E = -1200.0, earnings = 4175.0
# 2019-11-16 09:00:00: P = -100.0, E = -1300.0, earnings = 4151.0
# 2019-11-16 10:00:00: P = 100.0, E = -1200.0, earnings = -4108.0
# 2019-11-16 11:00:00: P = 100.0, E = -1100.0, earnings = -4026.0
# 2019-11-16 12:00:00: P = 100.0, E = -1000.0, earnings = -3994.0
# 2019-11-16 13:00:00: P = 100.0, E = -900.0, earnings = -4011.9999999999995
# 2019-11-16 14:00:00: P = 100.0, E = -800.0, earnings = -4019.0
# 2019-11-16 15:00:00: P = -100.0, E = -900.0, earnings = 4125.0
# 2019-11-16 16:00:00: P = -100.0, E = -1000.0, earnings = 4247.0
# 2019-11-16 17:00:00: P = -100.0, E = -1100.0, earnings = 4155.0
# 2019-11-16 18:00:00: P = 100.0, E = -1000.0, earnings = -3997.9999999999995
# 2019-11-16 19:00:00: P = 100.0, E = -900.0, earnings = -3863.0000000000005
# 2019-11-16 20:00:00: P = 100.0, E = -800.0, earnings = -3858.0
# 2019-11-16 21:00:00: P = 100.0, E = -700.0, earnings = -3729.0
# 2019-11-16 22:00:00: P = 100.0, E = -600.0, earnings = -3726.0
# 2019-11-16 23:00:00: P = 100.0, E = -500.0, earnings = -3486.9999999999995
# 2019-11-17 00:00:00: P = 100.0, E = -400.0, earnings = -3445.0000000000005
# 2019-11-17 01:00:00: P = 100.0, E = -300.0, earnings = -3406.0
# 2019-11-17 02:00:00: P = 100.0, E = -200.0, earnings = -3379.9999999999995
# 2019-11-17 03:00:00: P = 100.0, E = -100.0, earnings = -3415.0
# 2019-11-17 04:00:00: P = 100.0, E = 0.0, earnings = -3440.9999999999995
# 2019-11-17 05:00:00: P = 100.0, E = 100.0, earnings = -3433.0
# 2019-11-17 06:00:00: P = 100.0, E = 200.0, earnings = -3496.0
# 2019-11-17 07:00:00: P = 100.0, E = 300.0, earnings = -3685.0
# 2019-11-17 08:00:00: P = 100.0, E = 400.0, earnings = -3881.0
# 2019-11-17 09:00:00: P = 100.0, E = 500.0, earnings = -3972.0
# 2019-11-17 10:00:00: P = -100.0, E = 400.0, earnings = 4076.0
# 2019-11-17 11:00:00: P = 100.0, E = 500.0, earnings = -4015.0
# 2019-11-17 12:00:00: P = 0.0, E = 500.0, earnings = -0.0
# 2019-11-17 13:00:00: P = -100.0, E = 400.0, earnings = 4026.0
# 2019-11-17 14:00:00: P = -100.0, E = 300.0, earnings = 4079.9999999999995
# 2019-11-17 15:00:00: P = -100.0, E = 200.0, earnings = 4179.0
# 2019-11-17 16:00:00: P = -100.0, E = 100.0, earnings = 4398.0
# 2019-11-17 17:00:00: P = -100.0, E = 0.0, earnings = 4348.0
# 2019-11-17 18:00:00: P = -100.0, E = -100.0, earnings = 4192.0
# 2019-11-17 19:00:00: P = -100.0, E = -200.0, earnings = 4085.0
# 2019-11-17 20:00:00: P = 100.0, E = -100.0, earnings = -3997.0
# 2019-11-17 21:00:00: P = 100.0, E = 0.0, earnings = -3864.0
# 2019-11-17 22:00:00: P = 100.0, E = 100.0, earnings = -3711.0
# 2019-11-17 23:00:00: P = 100.0, E = 200.0, earnings = -3793.0
# 2019-11-18 00:00:00: P = 100.0, E = 300.0, earnings = -3724.0
# 2019-11-18 01:00:00: P = 100.0, E = 400.0, earnings = -3681.0
# 2019-11-18 02:00:00: P = 100.0, E = 500.0, earnings = -3688.0000000000005
# 2019-11-18 03:00:00: P = 100.0, E = 600.0, earnings = -3867.0
# 2019-11-18 04:00:00: P = 100.0, E = 700.0, earnings = -3990.9999999999995
# 2019-11-18 05:00:00: P = -100.0, E = 600.0, earnings = 4134.0
# 2019-11-18 06:00:00: P = -100.0, E = 500.0, earnings = 4314.0
# 2019-11-18 07:00:00: P = -100.0, E = 400.0, earnings = 4440.0
# 2019-11-18 08:00:00: P = -100.0, E = 300.0, earnings = 4489.0
# 2019-11-18 09:00:00: P = -100.0, E = 200.0, earnings = 4446.0
# 2019-11-18 10:00:00: P = -100.0, E = 100.0, earnings = 4397.0
# 2019-11-18 11:00:00: P = -100.0, E = 0.0, earnings = 4379.0
# 2019-11-18 12:00:00: P = -100.0, E = -100.0, earnings = 4357.0
# 2019-11-18 13:00:00: P = -100.0, E = -200.0, earnings = 4360.0
# 2019-11-18 14:00:00: P = -100.0, E = -300.0, earnings = 4377.0
# 2019-11-18 15:00:00: P = -100.0, E = -400.0, earnings = 4446.0
# 2019-11-18 16:00:00: P = -100.0, E = -500.0, earnings = 4435.0
# 2019-11-18 17:00:00: P = -100.0, E = -600.0, earnings = 4311.0
# 2019-11-18 18:00:00: P = -100.0, E = -700.0, earnings = 4162.0
# 2019-11-18 19:00:00: P = -100.0, E = -800.0, earnings = 4070.0000000000005
# 2019-11-18 20:00:00: P = 100.0, E = -700.0, earnings = -4038.0000000000005
# 2019-11-18 21:00:00: P = 100.0, E = -600.0, earnings = -3961.9999999999995
# 2019-11-18 22:00:00: P = 100.0, E = -500.0, earnings = -3928.0
# 2019-11-18 23:00:00: P = 100.0, E = -400.0, earnings = -3590.0
# 2019-11-19 00:00:00: P = 100.0, E = -300.0, earnings = -3485.0
# 2019-11-19 01:00:00: P = 100.0, E = -200.0, earnings = -3431.0
# 2019-11-19 02:00:00: P = 100.0, E = -100.0, earnings = -3428.0
# 2019-11-19 03:00:00: P = 100.0, E = 0.0, earnings = -3563.0000000000005
# 2019-11-19 04:00:00: P = 100.0, E = 100.0, earnings = -3815.9999999999995
# 2019-11-19 05:00:00: P = 100.0, E = 200.0, earnings = -3975.0
# 2019-11-19 06:00:00: P = -100.0, E = 100.0, earnings = 4193.0
# 2019-11-19 07:00:00: P = -100.0, E = 0.0, earnings = 4342.0
# 2019-11-19 08:00:00: P = -100.0, E = -100.0, earnings = 4199.0
# 2019-11-19 09:00:00: P = -100.0, E = -200.0, earnings = 4170.0
# 2019-11-19 10:00:00: P = -100.0, E = -300.0, earnings = 4177.0
# 2019-11-19 11:00:00: P = -100.0, E = -400.0, earnings = 4196.0
# 2019-11-19 12:00:00: P = -100.0, E = -500.0, earnings = 4311.0
# 2019-11-19 13:00:00: P = -100.0, E = -600.0, earnings = 4287.0
# 2019-11-19 14:00:00: P = -100.0, E = -700.0, earnings = 4312.0
# 2019-11-19 15:00:00: P = -100.0, E = -800.0, earnings = 4361.0
# 2019-11-19 16:00:00: P = -100.0, E = -900.0, earnings = 4358.0
# 2019-11-19 17:00:00: P = -100.0, E = -1000.0, earnings = 4291.0
# 2019-11-19 18:00:00: P = -100.0, E = -1100.0, earnings = 4200.0
# 2019-11-19 19:00:00: P = -100.0, E = -1200.0, earnings = 4163.0
# 2019-11-19 20:00:00: P = -100.0, E = -1300.0, earnings = 4127.0
# 2019-11-19 21:00:00: P = 100.0, E = -1200.0, earnings = -4063.0000000000005
# 2019-11-19 22:00:00: P = 100.0, E = -1100.0, earnings = -3861.0
# 2019-11-19 23:00:00: P = 100.0, E = -1000.0, earnings = -3877.0000000000005
# 2019-11-20 00:00:00: P = 100.0, E = -900.0, earnings = -3896.0
# 2019-11-20 01:00:00: P = 100.0, E = -800.0, earnings = -3875.0
# 2019-11-20 02:00:00: P = 100.0, E = -700.0, earnings = -3910.0
# 2019-11-20 03:00:00: P = 100.0, E = -600.0, earnings = -3950.0
# 2019-11-20 04:00:00: P = 100.0, E = -500.0, earnings = -4079.0
# 2019-11-20 05:00:00: P = -100.0, E = -600.0, earnings = 4230.0
# 2019-11-20 06:00:00: P = -100.0, E = -700.0, earnings = 4496.0
# 2019-11-20 07:00:00: P = -100.0, E = -800.0, earnings = 4546.0
# 2019-11-20 08:00:00: P = -100.0, E = -900.0, earnings = 4566.0
# 2019-11-20 09:00:00: P = -100.0, E = -1000.0, earnings = 4581.0
# 2019-11-20 10:00:00: P = -100.0, E = -1100.0, earnings = 4580.0
# 2019-11-20 11:00:00: P = -100.0, E = -1200.0, earnings = 4724.0
# 2019-11-20 12:00:00: P = -100.0, E = -1300.0, earnings = 4696.0
# 2019-11-20 13:00:00: P = -100.0, E = -1400.0, earnings = 4744.0
# 2019-11-20 14:00:00: P = -100.0, E = -1500.0, earnings = 4647.0
# 2019-11-20 15:00:00: P = -100.0, E = -1600.0, earnings = 4605.0
# 2019-11-20 16:00:00: P = -100.0, E = -1700.0, earnings = 4781.0
# 2019-11-20 17:00:00: P = -100.0, E = -1800.0, earnings = 4602.0
# 2019-11-20 18:00:00: P = -100.0, E = -1900.0, earnings = 4385.0
# 2019-11-20 19:00:00: P = -100.0, E = -2000.0, earnings = 4239.0
# 2019-11-20 20:00:00: P = -100.0, E = -2100.0, earnings = 4160.0
# 2019-11-20 21:00:00: P = 100.0, E = -2000.0, earnings = -4009.0000000000005
# 2019-11-20 22:00:00: P = 100.0, E = -1900.0, earnings = -3665.0
# 2019-11-20 23:00:00: P = 100.0, E = -1800.0, earnings = -3845.0000000000005
# 2019-11-21 00:00:00: P = 100.0, E = -1700.0, earnings = -3759.0000000000005
# 2019-11-21 01:00:00: P = 100.0, E = -1600.0, earnings = -3697.0
# 2019-11-21 02:00:00: P = 100.0, E = -1500.0, earnings = -3732.0
# 2019-11-21 03:00:00: P = 100.0, E = -1400.0, earnings = -3839.0
# 2019-11-21 04:00:00: P = 100.0, E = -1300.0, earnings = -3996.0
# 2019-11-21 05:00:00: P = -100.0, E = -1400.0, earnings = 4200.0
# 2019-11-21 06:00:00: P = -100.0, E = -1500.0, earnings = 4461.0
# 2019-11-21 07:00:00: P = -100.0, E = -1600.0, earnings = 4451.0
# 2019-11-21 08:00:00: P = -100.0, E = -1700.0, earnings = 4376.0
# 2019-11-21 09:00:00: P = -100.0, E = -1800.0, earnings = 4326.0
# 2019-11-21 10:00:00: P = -100.0, E = -1900.0, earnings = 4299.0
# 2019-11-21 11:00:00: P = -100.0, E = -2000.0, earnings = 4327.0
# 2019-11-21 12:00:00: P = -100.0, E = -2100.0, earnings = 4388.0
# 2019-11-21 13:00:00: P = -100.0, E = -2200.0, earnings = 4361.0
# 2019-11-21 14:00:00: P = -100.0, E = -2300.0, earnings = 4360.0
# 2019-11-21 15:00:00: P = -100.0, E = -2400.0, earnings = 4362.0
# 2019-11-21 16:00:00: P = -100.0, E = -2500.0, earnings = 4372.0
# 2019-11-21 17:00:00: P = -100.0, E = -2600.0, earnings = 4336.0
# ...
# 2019-12-11 22:00:00: P = 100.0, E = 1600.0, earnings = -3461.0
# 2019-12-11 23:00:00: P = 100.0, E = 1700.0, earnings = -3359.0000000000005
# 2019-12-12 00:00:00: P = 100.0, E = 1800.0, earnings = -3497.0
# 2019-12-12 01:00:00: P = 100.0, E = 1900.0, earnings = -3431.0
# 2019-12-12 02:00:00: P = 100.0, E = 2000.0, earnings = -3465.0
# 2019-12-12 03:00:00: P = 100.0, E = 2100.0, earnings = -3518.0
# 2019-12-12 04:00:00: P = -100.0, E = 2000.0, earnings = 3697.9999999999995
# 2019-12-12 05:00:00: P = -100.0, E = 1900.0, earnings = 3729.0
# 2019-12-12 06:00:00: P = -100.0, E = 1800.0, earnings = 3770.0000000000005
# 2019-12-12 07:00:00: P = -100.0, E = 1700.0, earnings = 3758.0
# 2019-12-12 08:00:00: P = -100.0, E = 1600.0, earnings = 3834.0000000000005
# 2019-12-12 09:00:00: P = -100.0, E = 1500.0, earnings = 3833.0
# 2019-12-12 10:00:00: P = -100.0, E = 1400.0, earnings = 3843.0
# 2019-12-12 11:00:00: P = -100.0, E = 1300.0, earnings = 3843.0
# 2019-12-12 12:00:00: P = -100.0, E = 1200.0, earnings = 3876.0
# 2019-12-12 13:00:00: P = -100.0, E = 1100.0, earnings = 3879.0
# 2019-12-12 14:00:00: P = -100.0, E = 1000.0, earnings = 3896.0
# 2019-12-12 15:00:00: P = -100.0, E = 900.0, earnings = 3802.0000000000005
# 2019-12-12 16:00:00: P = -100.0, E = 800.0, earnings = 3779.9999999999995
# 2019-12-12 17:00:00: P = -100.0, E = 700.0, earnings = 3797.9999999999995
# 2019-12-12 18:00:00: P = -100.0, E = 600.0, earnings = 3804.0
# 2019-12-12 19:00:00: P = -100.0, E = 500.0, earnings = 3770.0000000000005
# 2019-12-12 20:00:00: P = -100.0, E = 400.0, earnings = 3690.9999999999995
# 2019-12-12 21:00:00: P = 100.0, E = 500.0, earnings = -3601.0
# 2019-12-12 22:00:00: P = 100.0, E = 600.0, earnings = -3396.0
# 2019-12-12 23:00:00: P = 100.0, E = 700.0, earnings = -3265.9999999999995
# 2019-12-13 00:00:00: P = 100.0, E = 800.0, earnings = -3148.0
# 2019-12-13 01:00:00: P = 100.0, E = 900.0, earnings = -3076.0
# 2019-12-13 02:00:00: P = 100.0, E = 1000.0, earnings = -3069.0
# 2019-12-13 03:00:00: P = 100.0, E = 1100.0, earnings = -3309.0000000000005
# 2019-12-13 04:00:00: P = 100.0, E = 1200.0, earnings = -3549.0
# 2019-12-13 05:00:00: P = -100.0, E = 1100.0, earnings = 3635.0
# 2019-12-13 06:00:00: P = -100.0, E = 1000.0, earnings = 3795.0000000000005
# 2019-12-13 07:00:00: P = -100.0, E = 900.0, earnings = 3817.0
# 2019-12-13 08:00:00: P = -100.0, E = 800.0, earnings = 3818.0
# 2019-12-13 09:00:00: P = -100.0, E = 700.0, earnings = 3815.9999999999995
# 2019-12-13 10:00:00: P = -100.0, E = 600.0, earnings = 3811.9999999999995
# 2019-12-13 11:00:00: P = -100.0, E = 500.0, earnings = 3817.0
# 2019-12-13 12:00:00: P = -100.0, E = 400.0, earnings = 3822.9999999999995
# 2019-12-13 13:00:00: P = -100.0, E = 300.0, earnings = 3808.0
# 2019-12-13 14:00:00: P = -100.0, E = 200.0, earnings = 3819.0
# 2019-12-13 15:00:00: P = -100.0, E = 100.0, earnings = 3815.0
# 2019-12-13 16:00:00: P = -100.0, E = 0.0, earnings = 3800.0
# 2019-12-13 17:00:00: P = -100.0, E = -100.0, earnings = 3799.0
# 2019-12-13 18:00:00: P = -100.0, E = -200.0, earnings = 3796.0
# 2019-12-13 19:00:00: P = -100.0, E = -300.0, earnings = 3740.0
# 2019-12-13 20:00:00: P = 100.0, E = -200.0, earnings = -3651.0
# 2019-12-13 21:00:00: P = 100.0, E = -100.0, earnings = -3521.0
# 2019-12-13 22:00:00: P = 100.0, E = 0.0, earnings = -2961.0
# 2019-12-13 23:00:00: P = 100.0, E = 100.0, earnings = -3439.0
# 2019-12-14 00:00:00: P = 100.0, E = 200.0, earnings = -3261.9999999999995
# 2019-12-14 01:00:00: P = 100.0, E = 300.0, earnings = -3183.0
# 2019-12-14 02:00:00: P = 100.0, E = 400.0, earnings = -3105.0
# 2019-12-14 03:00:00: P = 100.0, E = 500.0, earnings = -3113.0
# 2019-12-14 04:00:00: P = 100.0, E = 600.0, earnings = -3177.0
# 2019-12-14 05:00:00: P = 100.0, E = 700.0, earnings = -3259.0000000000005
# 2019-12-14 06:00:00: P = 100.0, E = 800.0, earnings = -3331.0
# 2019-12-14 07:00:00: P = 100.0, E = 900.0, earnings = -3419.0
# 2019-12-14 08:00:00: P = 100.0, E = 1000.0, earnings = -3526.0
# 2019-12-14 09:00:00: P = 100.0, E = 1100.0, earnings = -3529.9999999999995
# 2019-12-14 10:00:00: P = 100.0, E = 1200.0, earnings = -3506.0
# 2019-12-14 11:00:00: P = 100.0, E = 1300.0, earnings = -3547.9999999999995
# 2019-12-14 12:00:00: P = 100.0, E = 1400.0, earnings = -3549.0
# 2019-12-14 13:00:00: P = 100.0, E = 1500.0, earnings = -3554.0
# 2019-12-14 14:00:00: P = 0.0, E = 1500.0, earnings = -0.0
# 2019-12-14 15:00:00: P = -100.0, E = 1400.0, earnings = 3635.0
# 2019-12-14 16:00:00: P = -100.0, E = 1300.0, earnings = 3665.0
# 2019-12-14 17:00:00: P = 100.0, E = 1400.0, earnings = -3577.0000000000005
# 2019-12-14 18:00:00: P = 100.0, E = 1500.0, earnings = -3493.0
# 2019-12-14 19:00:00: P = 100.0, E = 1600.0, earnings = -3392.0
# 2019-12-14 20:00:00: P = 100.0, E = 1700.0, earnings = -3314.0
# 2019-12-14 21:00:00: P = 100.0, E = 1800.0, earnings = -3217.0
# 2019-12-14 22:00:00: P = 100.0, E = 1900.0, earnings = -3238.0000000000005
# 2019-12-14 23:00:00: P = 100.0, E = 2000.0, earnings = -3063.0
# 2019-12-15 00:00:00: P = 100.0, E = 2100.0, earnings = -3016.0
# 2019-12-15 01:00:00: P = 100.0, E = 2200.0, earnings = -3004.0
# 2019-12-15 02:00:00: P = 100.0, E = 2300.0, earnings = -3007.0
# 2019-12-15 03:00:00: P = 100.0, E = 2400.0, earnings = -3038.0
# 2019-12-15 04:00:00: P = 100.0, E = 2500.0, earnings = -2260.0
# 2019-12-15 05:00:00: P = 100.0, E = 2600.0, earnings = -2694.0
# 2019-12-15 06:00:00: P = 100.0, E = 2700.0, earnings = -3057.0
# 2019-12-15 07:00:00: P = 100.0, E = 2800.0, earnings = -3168.0
# 2019-12-15 08:00:00: P = 100.0, E = 2900.0, earnings = -3344.0
# 2019-12-15 09:00:00: P = 100.0, E = 3000.0, earnings = -3428.0
# 2019-12-15 10:00:00: P = 100.0, E = 3100.0, earnings = -3492.0
# 2019-12-15 11:00:00: P = 100.0, E = 3200.0, earnings = -3488.0000000000005
# 2019-12-15 12:00:00: P = 100.0, E = 3300.0, earnings = -3481.0
# 2019-12-15 13:00:00: P = 100.0, E = 3400.0, earnings = -3471.0
# 2019-12-15 14:00:00: P = -100.0, E = 3300.0, earnings = 3583.0
# 2019-12-15 15:00:00: P = -100.0, E = 3200.0, earnings = 3671.0
# 2019-12-15 16:00:00: P = -100.0, E = 3100.0, earnings = 3690.9999999999995
# 2019-12-15 17:00:00: P = -100.0, E = 3000.0, earnings = 3626.0
# 2019-12-15 18:00:00: P = -100.0, E = 2900.0, earnings = 3563.0000000000005
# 2019-12-15 19:00:00: P = 100.0, E = 3000.0, earnings = -3479.0
# 2019-12-15 20:00:00: P = 100.0, E = 3100.0, earnings = -3436.0
# 2019-12-15 21:00:00: P = 100.0, E = 3200.0, earnings = -3404.0
# 2019-12-15 22:00:00: P = -100.0, E = 3100.0, earnings = 3622.0
# 2019-12-15 23:00:00: P = 100.0, E = 3200.0, earnings = -3286.9999999999995
# 2019-12-16 00:00:00: P = 100.0, E = 3300.0, earnings = -3270.0000000000005
# 2019-12-16 01:00:00: P = 100.0, E = 3400.0, earnings = -3275.0
# 2019-12-16 02:00:00: P = 100.0, E = 3500.0, earnings = -3347.0
# 2019-12-16 03:00:00: P = 100.0, E = 3600.0, earnings = -3513.0000000000005
# 2019-12-16 04:00:00: P = -100.0, E = 3500.0, earnings = 3684.0000000000005
# 2019-12-16 05:00:00: P = -100.0, E = 3400.0, earnings = 3886.9999999999995
# 2019-12-16 06:00:00: P = -100.0, E = 3300.0, earnings = 4054.9999999999995
# 2019-12-16 07:00:00: P = -100.0, E = 3200.0, earnings = 4288.0
# 2019-12-16 08:00:00: P = -100.0, E = 3100.0, earnings = 4200.0
# 2019-12-16 09:00:00: P = -100.0, E = 3000.0, earnings = 4120.0
# 2019-12-16 10:00:00: P = -100.0, E = 2900.0, earnings = 4083.0
# 2019-12-16 11:00:00: P = -100.0, E = 2800.0, earnings = 4110.0
# 2019-12-16 12:00:00: P = -100.0, E = 2700.0, earnings = 4127.0
# 2019-12-16 13:00:00: P = -100.0, E = 2600.0, earnings = 4141.0
# 2019-12-16 14:00:00: P = -100.0, E = 2500.0, earnings = 4232.0
# 2019-12-16 15:00:00: P = -100.0, E = 2400.0, earnings = 4164.0
# 2019-12-16 16:00:00: P = -100.0, E = 2300.0, earnings = 4099.0
# 2019-12-16 17:00:00: P = -100.0, E = 2200.0, earnings = 4082.0
# 2019-12-16 18:00:00: P = -100.0, E = 2100.0, earnings = 4068.0
# 2019-12-16 19:00:00: P = -100.0, E = 2000.0, earnings = 4017.0
# 2019-12-16 20:00:00: P = -100.0, E = 1900.0, earnings = 3914.0
# 2019-12-16 21:00:00: P = -100.0, E = 1800.0, earnings = 3786.0
# 2019-12-16 22:00:00: P = 100.0, E = 1900.0, earnings = -3550.0
# 2019-12-16 23:00:00: P = 100.0, E = 2000.0, earnings = -3568.0
# 2019-12-17 00:00:00: P = 100.0, E = 2100.0, earnings = -3467.0
# 2019-12-17 01:00:00: P = 100.0, E = 2200.0, earnings = -3465.9999999999995
# 2019-12-17 02:00:00: P = 100.0, E = 2300.0, earnings = -3493.0
# 2019-12-17 03:00:00: P = -100.0, E = 2200.0, earnings = 3606.0
# 2019-12-17 04:00:00: P = -100.0, E = 2100.0, earnings = 3711.0
# 2019-12-17 05:00:00: P = -100.0, E = 2000.0, earnings = 3794.0
# 2019-12-17 06:00:00: P = -100.0, E = 1900.0, earnings = 4038.0000000000005
# 2019-12-17 07:00:00: P = -100.0, E = 1800.0, earnings = 4045.0000000000005
# 2019-12-17 08:00:00: P = -100.0, E = 1700.0, earnings = 4025.0
# 2019-12-17 09:00:00: P = -100.0, E = 1600.0, earnings = 4015.0
# 2019-12-17 10:00:00: P = -100.0, E = 1500.0, earnings = 3917.0
# 2019-12-17 11:00:00: P = -100.0, E = 1400.0, earnings = 3888.0000000000005
# 2019-12-17 12:00:00: P = -100.0, E = 1300.0, earnings = 3904.9999999999995
# 2019-12-17 13:00:00: P = -100.0, E = 1200.0, earnings = 3960.0
# 2019-12-17 14:00:00: P = -100.0, E = 1100.0, earnings = 4043.0
# 2019-12-17 15:00:00: P = -100.0, E = 1000.0, earnings = 4053.0
# 2019-12-17 16:00:00: P = -100.0, E = 900.0, earnings = 4049.0
# 2019-12-17 17:00:00: P = -100.0, E = 800.0, earnings = 3879.0
# 2019-12-17 18:00:00: P = -100.0, E = 700.0, earnings = 3796.0
# 2019-12-17 19:00:00: P = -100.0, E = 600.0, earnings = 3721.0
# 2019-12-17 20:00:00: P = -100.0, E = 500.0, earnings = 3732.0
# 2019-12-17 21:00:00: P = -100.0, E = 400.0, earnings = 3693.0
# 2019-12-17 22:00:00: P = 100.0, E = 500.0, earnings = -3378.0
# 2019-12-17 23:00:00: P = 100.0, E = 600.0, earnings = -3393.0
# 2019-12-18 00:00:00: P = 100.0, E = 700.0, earnings = -3328.0
# 2019-12-18 01:00:00: P = 100.0, E = 800.0, earnings = -3294.0
# 2019-12-18 02:00:00: P = 100.0, E = 900.0, earnings = -3295.0000000000005
# 2019-12-18 03:00:00: P = 100.0, E = 1000.0, earnings = -3415.9999999999995
# 2019-12-18 04:00:00: P = -100.0, E = 900.0, earnings = 3675.0
# 2019-12-18 05:00:00: P = -100.0, E = 800.0, earnings = 3761.0
# 2019-12-18 06:00:00: P = -100.0, E = 700.0, earnings = 3995.0000000000005
# 2019-12-18 07:00:00: P = -100.0, E = 600.0, earnings = 4076.0
# 2019-12-18 08:00:00: P = -100.0, E = 500.0, earnings = 4119.0
# 2019-12-18 09:00:00: P = -100.0, E = 400.0, earnings = 4063.0000000000005
# 2019-12-18 10:00:00: P = -100.0, E = 300.0, earnings = 4018.0
# 2019-12-18 11:00:00: P = -100.0, E = 200.0, earnings = 3988.0000000000005
# 2019-12-18 12:00:00: P = -100.0, E = 100.0, earnings = 3979.9999999999995
# 2019-12-18 13:00:00: P = -100.0, E = 0.0, earnings = 3988.0000000000005
# 2019-12-18 14:00:00: P = -100.0, E = -100.0, earnings = 4006.0
# 2019-12-18 15:00:00: P = -100.0, E = -200.0, earnings = 3979.0
# 2019-12-18 16:00:00: P = -100.0, E = -300.0, earnings = 3920.0000000000005
# 2019-12-18 17:00:00: P = -100.0, E = -400.0, earnings = 3894.0
# 2019-12-18 18:00:00: P = -100.0, E = -500.0, earnings = 3876.0
# 2019-12-18 19:00:00: P = -100.0, E = -600.0, earnings = 3869.0
# 2019-12-18 20:00:00: P = -100.0, E = -700.0, earnings = 3804.9999999999995
# 2019-12-18 21:00:00: P = 100.0, E = -600.0, earnings = -3633.0
# 2019-12-18 22:00:00: P = 100.0, E = -500.0, earnings = -3283.0
# 2019-12-18 23:00:00: P = 100.0, E = -400.0, earnings = -3454.0
# 2019-12-19 00:00:00: P = 100.0, E = -300.0, earnings = -3429.9999999999995
# 2019-12-19 01:00:00: P = 100.0, E = -200.0, earnings = -3392.0
# 2019-12-19 02:00:00: P = 100.0, E = -100.0, earnings = -3436.9999999999995
# 2019-12-19 03:00:00: P = 100.0, E = 0.0, earnings = -3527.0000000000005
# 2019-12-19 04:00:00: P = 100.0, E = 100.0, earnings = -3639.0
# 2019-12-19 05:00:00: P = -100.0, E = 0.0, earnings = 3710.0
# 2019-12-19 06:00:00: P = -100.0, E = -100.0, earnings = 3892.0
# 2019-12-19 07:00:00: P = -100.0, E = -200.0, earnings = 4009.0000000000005
# 2019-12-19 08:00:00: P = -100.0, E = -300.0, earnings = 3961.9999999999995
# 2019-12-19 09:00:00: P = -100.0, E = -400.0, earnings = 3804.0
# 2019-12-19 10:00:00: P = -100.0, E = -500.0, earnings = 3769.0
# 2019-12-19 11:00:00: P = -100.0, E = -600.0, earnings = 3757.0
# 2019-12-19 12:00:00: P = -100.0, E = -700.0, earnings = 3767.0
# 2019-12-19 13:00:00: P = -100.0, E = -800.0, earnings = 3801.0
# 2019-12-19 14:00:00: P = -100.0, E = -900.0, earnings = 3872.0
# 2019-12-19 15:00:00: P = -100.0, E = -1000.0, earnings = 3949.0
# 2019-12-19 16:00:00: P = -100.0, E = -1100.0, earnings = 3936.0
# 2019-12-19 17:00:00: P = -100.0, E = -1200.0, earnings = 3881.0
# 2019-12-19 18:00:00: P = -100.0, E = -1300.0, earnings = 3796.0
# 2019-12-19 19:00:00: P = 100.0, E = -1200.0, earnings = -3693.0
# 2019-12-19 20:00:00: P = 100.0, E = -1100.0, earnings = -3595.0000000000005
# 2019-12-19 21:00:00: P = 100.0, E = -1000.0, earnings = -3414.0
# 2019-12-19 22:00:00: P = 100.0, E = -900.0, earnings = -3269.0
# 2019-12-19 23:00:00: P = 100.0, E = -800.0, earnings = -3233.0
# 2019-12-20 00:00:00: P = 100.0, E = -700.0, earnings = -3225.0
# 2019-12-20 01:00:00: P = 100.0, E = -600.0, earnings = -3226.0
# 2019-12-20 02:00:00: P = 100.0, E = -500.0, earnings = -3194.0
# 2019-12-20 03:00:00: P = 100.0, E = -400.0, earnings = -3379.9999999999995
# 2019-12-20 04:00:00: P = 100.0, E = -300.0, earnings = -3599.0
# 2019-12-20 05:00:00: P = 100.0, E = -200.0, earnings = -3668.0
# 2019-12-20 06:00:00: P = -100.0, E = -300.0, earnings = 3756.0
# 2019-12-20 07:00:00: P = -100.0, E = -400.0, earnings = 3813.0000000000005
# 2019-12-20 08:00:00: P = -100.0, E = -500.0, earnings = 3804.9999999999995
# 2019-12-20 09:00:00: P = -100.0, E = -600.0, earnings = 3794.0
# 2019-12-20 10:00:00: P = -100.0, E = -700.0, earnings = 3794.0
# 2019-12-20 11:00:00: P = -100.0, E = -800.0, earnings = 3777.0000000000005
# 2019-12-20 12:00:00: P = -100.0, E = -900.0, earnings = 3759.0000000000005
# 2019-12-20 13:00:00: P = -100.0, E = -1000.0, earnings = 3749.0
# 2019-12-20 14:00:00: P = -100.0, E = -1100.0, earnings = 3742.0
# 2019-12-20 15:00:00: P = -100.0, E = -1200.0, earnings = 3746.0
# 2019-12-20 16:00:00: P = -100.0, E = -1300.0, earnings = 3745.0000000000005
# 2019-12-20 17:00:00: P = -100.0, E = -1400.0, earnings = 3747.9999999999995
# 2019-12-20 18:00:00: P = 100.0, E = -1300.0, earnings = -3700.0
# 2019-12-20 19:00:00: P = 100.0, E = -1200.0, earnings = -3615.9999999999995
# 2019-12-20 20:00:00: P = 100.0, E = -1100.0, earnings = -3578.0
# 2019-12-20 21:00:00: P = 100.0, E = -1000.0, earnings = -3438.0000000000005
# 2019-12-20 22:00:00: P = 100.0, E = -900.0, earnings = -3420.0000000000005
# 2019-12-20 23:00:00: P = 100.0, E = -800.0, earnings = -2740.0
# 2019-12-21 00:00:00: P = 100.0, E = -700.0, earnings = -2908.0
# 2019-12-21 01:00:00: P = 100.0, E = -600.0, earnings = -2903.0
# 2019-12-21 02:00:00: P = 100.0, E = -500.0, earnings = -3083.0
# 2019-12-21 03:00:00: P = 100.0, E = -400.0, earnings = -3167.0
# 2019-12-21 04:00:00: P = 100.0, E = -300.0, earnings = -3126.0
# 2019-12-21 05:00:00: P = 100.0, E = -200.0, earnings = -3301.0
# 2019-12-21 06:00:00: P = 100.0, E = -100.0, earnings = -3393.0
# 2019-12-21 07:00:00: P = 100.0, E = 0.0, earnings = -3469.0
# 2019-12-21 08:00:00: P = 100.0, E = 100.0, earnings = -3590.0
# 2019-12-21 09:00:00: P = 100.0, E = 200.0, earnings = -3600.0
# 2019-12-21 10:00:00: P = 100.0, E = 300.0, earnings = -3632.0
# 2019-12-21 11:00:00: P = 100.0, E = 400.0, earnings = -3622.9999999999995
# 2019-12-21 12:00:00: P = 100.0, E = 500.0, earnings = -3615.9999999999995
# 2019-12-21 13:00:00: P = -100.0, E = 400.0, earnings = 3678.0
# 2019-12-21 14:00:00: P = -100.0, E = 300.0, earnings = 3743.0
# 2019-12-21 15:00:00: P = -100.0, E = 200.0, earnings = 3817.0
# 2019-12-21 16:00:00: P = -100.0, E = 100.0, earnings = 3829.0
# 2019-12-21 17:00:00: P = -100.0, E = 0.0, earnings = 3776.0
# 2019-12-21 18:00:00: P = -100.0, E = -100.0, earnings = 3692.0
# 2019-12-21 19:00:00: P = 100.0, E = 0.0, earnings = -3590.0
# 2019-12-21 20:00:00: P = 100.0, E = 100.0, earnings = -3565.9999999999995
# 2019-12-21 21:00:00: P = 100.0, E = 200.0, earnings = -3511.0
# 2019-12-21 22:00:00: P = 100.0, E = 300.0, earnings = -3379.0
# 2019-12-21 23:00:00: P = 100.0, E = 400.0, earnings = -3376.0
# 2019-12-22 00:00:00: P = 100.0, E = 500.0, earnings = -3361.0

# %% [markdown]
# Since running the model for many time-steps may take a long time, i recommend storing the results. Then when you start working on the visualization on a later day, you can just load the stored results instead of running your model again. One easy way to store python objects is using pickle, which is also integrated in pandas, see this example:

# %%
# Convert results to pickle format, so that we can export it
pd.to_pickle(results_perfect, "perfect.pkl") 
pd.to_pickle(results_lastweek, "lastweek.pkl")

# %%
# Store results on local disk to be accessed later
results_perfect = pd.read_pickle("perfect.pkl")
results_lastweek = pd.read_pickle("lastweek.pkl")

# %% [markdown]
# ## Plotting the results
# For these graphs, you should plot the results for both the "perfect prediction" and the "last week prediction". If you have implemented any other prediction method, you can also implement that.
# For your results, please plot...
# * ... P(t) for the first 100 hours
# * ... E(t) for the first 100 hours
# * ... cummulative earnings over the entire time
#
# Using just the "last week prediction", plot...
# * ... the average P(t) and p(t) (power and price) for each hour of the day and each day of the week
#
# To show how the actual plant operation changes as new data becomes available, plot (for the first week, using only "last week prediction")...
# * ... actual E(t) vs E(t) as planned in first timestep

# %% [markdown]
# #### Plot P(t) for the first 100 hours

# %%
# Create dataframe that unifies the necessary information
df100hlast = results_lastweek[['Power']]
df100h = results_perfect[['Timeslot','Power']]
df100h = df100h.head(100)
df100h.columns = ['t','Perfect']
df100h['Last Week'] = df100hlast

# Plot data and assign attributes
ax = df100h.plot('t',['Perfect','Last Week'],title='Power (relative to nominal) over the first 100 hours',figsize=(14,10))
ax.set_ylabel("P(t) in MWh")
ax.set_xlabel("Date in Day-Month-Year")
ax.legend(title = "Prediction method")
plt.setp(ax.get_xticklabels(), rotation=45)
ax.legend(loc='best')
plt.show()

# %% [markdown]
# #### Plot E(t) for the first 100 hours

# %%
# Create dataframe that unifies the necessary information
df100hlastE = results_lastweek[['Energy']]
df100hE = results_perfect[['Timeslot','Energy']]
df100hE = df100hE.head(100)
df100hE.columns = ['t','Perfect']
df100hE['Last Week'] = df100hlastE

# Plot data and assign attributes
ax = df100hE.plot('t',['Perfect','Last Week'],title='Energy (relative to nominal) over the first 100 hours',figsize=(14,10))
ax.set_ylabel("E(t) in MWh")
ax.set_xlabel("Date in Day-Month-Year")
ax.legend(title = "Prediction method")
ax.legend(loc='best')
plt.setp(ax.get_xticklabels(), rotation=45)
plt.show()

# %% [markdown]
# #### Plot earnings

# %%
# Create dataframe that unifies the necessary information
dflastEa = results_lastweek[['Earnings']]
dfEa = results_perfect[['Timeslot','Earnings']]
dfEa.columns = ['t','Perfect']
dfEa['Last Week'] = dflastEa

# Compute cummulatative sum
lastPerfect = 0
lastLastWeek = 0
for index, row in dfEa.iterrows():
    if index != 0:
        dfEa.loc[index, 'Perfect']  += lastPerfect
        dfEa.loc[index, 'Last Week'] += lastLastWeek
    lastPerfect = dfEa.loc[index, 'Perfect']
    lastLastWeek = dfEa.loc[index, 'Last Week']

# Plot data and assign attributes    
ax = dfEa.plot('t',['Perfect','Last Week'],title='Cummulative Earnings', figsize=(14,10))
ax.set_ylabel("Earnings in €")
ax.set_xlabel("Date in Day-Month-Year")
ax.legend(title = "Prediction method")
ax.legend(loc='best')
plt.setp(ax.get_xticklabels(), rotation=45)
plt.show()
# Out:
# <ipython-input-107-0659abe3dee2>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfEa['Last Week'] = dflastEa
# D:\Program Files\Anaconda\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %% [markdown]
# #### Average Power and electricity price for each hour of the day and each day of the week
# Please note that the second y axis is inverted. This is not a data viz course, so sue me

# %%
# Create dataframe that unifies the necessary information
results_dates = results_lastweek.copy(deep=True)
timestamps = results_dates.index
for index, row in results_dates.iterrows():
    results_dates.loc[index, 'Date'] = results_dates.loc[index, 'Timeslot'].hour

grouped_res = results_dates.groupby(['Date']).mean()
grouped_res = grouped_res[['Power']]

prices = df[["SE1"]].copy(deep=True)

for index, row in prices.iterrows():
    prices.loc[index, 'Weekday'] = index.hour
grouped_pric = prices.groupby(['Weekday']).mean()
grouped_pric = grouped_pric[['SE1']]

# Plot data and assign attributes  
ax = grouped_res.plot(title='Average power and electricity price per day of the week',figsize=(14,10))
ax.set_ylabel("Average Power in MW")
ax.set_xlabel("Hour of the day")
ax2 = ax.twinx()
ax2.plot(grouped_pric, color="red", label = "Price")
ax.legend(loc='upper right')
ax2.invert_yaxis()
ax2.set_ylabel("Average Price in €/MWh")
ax2.legend(loc='lower right')
plt.show()

# %%
# Create dataframe that unifies the necessary information
results_dates = results_lastweek.copy(deep=True)
timestamps = results_dates.index
for index, row in results_dates.iterrows():
    results_dates.loc[index, 'Date'] = results_dates.loc[index, 'Timeslot'].weekday()
grouped_res = results_dates.groupby(['Date']).mean()
grouped_res = grouped_res[['Power']]

prices = df[["SE1"]].copy(deep=True)

for index, row in prices.iterrows():
    prices.loc[index, 'Weekday'] = index.weekday()
grouped_pric = prices.groupby(['Weekday']).mean()
grouped_pric = grouped_pric[['SE1']]

# Plot data and assign attributes  
ax = grouped_res.plot(title = 'Average power and electricity price per day of the week',figsize=(14,10))
ax.set_ylabel("Average Power in MW")
ax.set_xlabel("Hour of the day")
ax2 = ax.twinx()
ax2.plot(grouped_pric, color="red", label = "Price")
ax2.invert_yaxis()
ax2.set_ylabel("Average Price in €/MWh")
ax.legend(loc = 'upper right')
ax2.legend(loc = 'lower right')
plt.show()

# %% [markdown]
# #### Plot actual E(t) for the first week versus E(t) from first iteration of optimization

# %%
# Create dataframe that unifies the necessary information
df168hE = results_lastweek[['Timeslot','Energy']]
df168hE = df168hE.head(168)
df168hE.columns = ['t','Actual']

predictor = PredictionGenerator(historic_prices, method="SameHourLastWeek")
prices = predictor.predict(t_start, t_horizon)
prices[t_start] = historic_prices[t_start]

model = solve(prices,Pmax,Emax,E0)

for index, row in df168hE.iterrows():
    df168hE.loc[index, 'Planned'] = model.getVarByName("E%s" % df168hE.loc[index, 't']).x

# Plot data and assign attributes  
ax = df168hE.plot('t',['Actual', 'Planned'],title='Energy (relative to nominal) actual versus planned at first timestep', figsize=(14,10))
ax.set_ylabel("E(t) in MWh")
ax.set_xlabel("Date in Day-Month-Year")
plt.show()
